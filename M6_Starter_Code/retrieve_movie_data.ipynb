# %% [markdown]
# ### Import Required Libraries and Set Up Environment Variables

# %%
# Dependencies
import requests
import time
from dotenv import load_dotenv
import os
import pandas as pd
import json

# %%
# Set environment variables from the .env in the local environment
load_dotenv()

nyt_api_key = os.getenv("NYT_API_KEY")
tmdb_api_key = os.getenv("TMDB_API_KEY")

# %% [markdown]
# ### Access the New York Times API

# %%
# Set the base URL
url = "https://api.nytimes.com/svc/search/v2/articlesearch.json?"

# Filter for movie reviews with "love" in the headline
# section_name should be "Movies"
# type_of_material should be "Review"
filter_query = 'section_name:"Movies" AND type_of_material:"Review" AND headline:"love"'

# Use a sort filter, sort by newest
sort = "newest"

# Select the following fields to return:
# headline, web_url, snippet, source, keywords, pub_date, byline, word_count
field_list = "headline,web_url,snippet,source,keywords,pub_date,byline,word_count"

# Search for reviews published between a begin and end date
begin_date = "20130101"
end_date = "20230531"

# Build URL
#query_url = (f"{url}api-key={nyt_api_key}")

query_url = (
    f"{url}api-key={nyt_api_key}&begin_date={begin_date}&end_date={end_date}"
    + f'&fq={filter_query}&sort={sort}&fl={field_list}'
)

# %%
# Create an empty list to store the reviews
reviews_list = []

# loop through pages 0-19
for page in range(0,20):
    # create query with a page number
    queryurl = f"{query_url}&page={page}"

    # API results show 10 articles at a time

    
    # Make a "GET" request and retrieve the JSON
    reviews = requests.get(queryurl).json()
    
    # Add a twelve second interval between queries to stay within API query limits
    time.sleep(12)
    
    # Try and save the reviews to the reviews_list
    try:
        # loop through the reviews["response"]["docs"] and append each review to the list
        for review in reviews["response"]["docs"]:
            reviews_list.append(review)
        # Print the page that was just retrieved
        print(f"checked page {page}")
    except:
        # Print the page number that had no results then break from the loop
        print(f"No results. Ended at page {page}.")
        break
# Out:
# checked page 0
# checked page 1
# checked page 2
# checked page 3
# checked page 4
# checked page 5
# checked page 6
# checked page 7
# checked page 8
# checked page 9
# checked page 10
# checked page 11
# checked page 12
# checked page 13
# checked page 14
# checked page 15
# checked page 16
# checked page 17
# checked page 18
# checked page 19

# %%
# Preview the first 5 results in JSON format
# Use json.dumps with argument indent=4 to format data
print(json.dumps(reviews_list[:5], indent=4))
# Out:
# [
#     {
#         "web_url": "https://www.nytimes.com/2023/05/25/movies/the-attachment-diaries-review.html",
#         "snippet": "A gynecologist and her patient form a horrifyingly twisted connection in this batty, bloody Argentine melodrama.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018The Attachment Diaries\u2019 Review: Love, Sick",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "The Attachment Diaries",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "The Attachment Diaries (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Diment, Valentin Javier",
#                 "rank": 3,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-05-25T11:00:03+0000",
#         "byline": {
#             "original": "By Jeannette Catsoulis",
#             "person": [
#                 {
#                     "firstname": "Jeannette",
#                     "middlename": null,
#                     "lastname": "Catsoulis",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 295
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/05/04/movies/whats-love-got-to-do-with-it-review.html",
#         "snippet": "Two childhood friends navigate cultural differences in this pleasantly uncontentious romantic comedy.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "Review: \u2018What\u2019s Love Got to Do With It?\u2019 Probably a Lot",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "What\u2019s Love Got to Do With It?",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Kapur, Shekhar",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "James, Lily",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Azmi, Shabana",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Thompson, Emma",
#                 "rank": 5,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-05-04T17:16:45+0000",
#         "byline": {
#             "original": "By Jeannette Catsoulis",
#             "person": [
#                 {
#                     "firstname": "Jeannette",
#                     "middlename": null,
#                     "lastname": "Catsoulis",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 287
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/05/04/movies/you-can-live-forever-review.html",
#         "snippet": "Religion comes between two girls falling in love in the 1990s in this sweet coming-of-age film bathed in grunge hues.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018You Can Live Forever\u2019 Review: Do You Love Me Now?",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "You Can Live Forever",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "You Can Live Forever (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Slutsky, Mark",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Watts, Sarah (Film Director)",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "O'Driscoll, Anwen",
#                 "rank": 5,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Laporte, June (Actor)",
#                 "rank": 6,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-05-04T11:00:08+0000",
#         "byline": {
#             "original": "By Elisabeth Vincentelli",
#             "person": [
#                 {
#                     "firstname": "Elisabeth",
#                     "middlename": null,
#                     "lastname": "Vincentelli",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 294
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/04/21/movies/a-tourists-guide-to-love-review.html",
#         "snippet": "Rachael Leigh Cook stars in this bland rom-com as a travel executive exploring Vietnam and getting over a breakup.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018A Tourist\u2019s Guide to Love\u2019 Review: A Wearyingly Familiar Trip",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "A Tourist\u2019s  Guide to Love",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "A Tourist's Guide to Love (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Tsuchida, Steven",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Cook, Rachael Leigh",
#                 "rank": 4,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-04-21T07:03:25+0000",
#         "byline": {
#             "original": "By Elisabeth Vincentelli",
#             "person": [
#                 {
#                     "firstname": "Elisabeth",
#                     "middlename": null,
#                     "lastname": "Vincentelli",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 276
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/04/20/movies/other-peoples-children-review.html",
#         "snippet": "A radiant Virginie Efira stars as a Parisian teacher who blissfully falls for a man and his 4-year-old daughter, complicating everyone\u2019s lives.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018Other People\u2019s Children\u2019 Review: True Romance",
#             "kicker": "Critic\u2019s pick",
#             "content_kicker": null,
#             "print_headline": "Intoxicating Love With a Sobering Turn",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Zlotowski, Rebecca",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "Other People's Children (Movie)",
#                 "rank": 3,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-04-20T15:35:13+0000",
#         "byline": {
#             "original": "By Manohla Dargis",
#             "person": [
#                 {
#                     "firstname": "Manohla",
#                     "middlename": null,
#                     "lastname": "Dargis",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 801
#     }
# ]

# %%
# Convert reviews_list to a Pandas DataFrame using json_normalize()
df_reviews = pd.json_normalize(reviews_list)
df_reviews
# Out:
#                                                web_url  \
# 0    https://www.nytimes.com/2023/05/25/movies/the-...
# 1    https://www.nytimes.com/2023/05/04/movies/what...
# 2    https://www.nytimes.com/2023/05/04/movies/you-...
# 3    https://www.nytimes.com/2023/04/21/movies/a-to...
# 4    https://www.nytimes.com/2023/04/20/movies/othe...
# ..                                                 ...
# 195  https://www.nytimes.com/2017/03/09/movies/the-...
# 196  https://www.nytimes.com/2017/03/09/movies/revi...
# 197  https://www.nytimes.com/2017/03/02/movies/love...
# 198  https://www.nytimes.com/2017/02/16/movies/ever...
# 199  https://www.nytimes.com/2017/02/09/movies/kedi...
#
#                                                snippet              source  \
# 0    A gynecologist and her patient form a horrifyi...  The New York Times
# 1    Two childhood friends navigate cultural differ...  The New York Times
# 2    Religion comes between two girls falling in lo...  The New York Times
# 3    Rachael Leigh Cook stars in this bland rom-com...  The New York Times
# 4    A radiant Virginie Efira stars as a Parisian t...  The New York Times
# ..                                                 ...                 ...
# 195  This moody romance stars Tatiana Maslany (“Orp...  The New York Times
# 196  A nurse travels to the Ottoman Empire on the e...  The New York Times
# 197  Josh Kornbluth runs afoul of the Internal Reve...  The New York Times
# 198  A messed-up heroine is asked to choose between...  The New York Times
# 199  This documentary profiles distinctive street c...  The New York Times
#
#                                               keywords  \
# 0    [{'name': 'subject', 'value': 'Movies', 'rank'...
# 1    [{'name': 'subject', 'value': 'Movies', 'rank'...
# 2    [{'name': 'subject', 'value': 'Movies', 'rank'...
# 3    [{'name': 'subject', 'value': 'Movies', 'rank'...
# 4    [{'name': 'subject', 'value': 'Movies', 'rank'...
# ..                                                 ...
# 195  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 196  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 197  [{'name': 'creative_works', 'value': 'Love & T...
# 198  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 199  [{'name': 'creative_works', 'value': 'Kedi (Mo...
#
#                      pub_date  word_count  \
# 0    2023-05-25T11:00:03+0000         295
# 1    2023-05-04T17:16:45+0000         287
# 2    2023-05-04T11:00:08+0000         294
# 3    2023-04-21T07:03:25+0000         276
# 4    2023-04-20T15:35:13+0000         801
# ..                        ...         ...
# 195  2017-03-09T21:54:58+0000         251
# 196  2017-03-09T21:53:12+0000         267
# 197  2017-03-02T21:44:18+0000         246
# 198  2017-02-16T21:45:50+0000         256
# 199  2017-02-09T16:21:39+0000         274
#
#                                          headline.main headline.kicker  \
# 0          ‘The Attachment Diaries’ Review: Love, Sick            None
# 1    Review: ‘What’s Love Got to Do With It?’ Proba...            None
# 2    ‘You Can Live Forever’ Review: Do You Love Me ...            None
# 3    ‘A Tourist’s Guide to Love’ Review: A Wearying...            None
# 4       ‘Other People’s Children’ Review: True Romance   Critic’s pick
# ..                                                 ...             ...
# 195  Review: A Combustible Pair Find Love in ‘The O...            None
# 196  Review: Love as the World Wars, in ‘The Ottoma...            None
# 197  Review: It’s All Mirth and Taxes in ‘Love & Ta...            None
# 198  Review: ‘Everybody Loves Somebody,’ a Rom-Com ...            None
# 199  Review: Cute Cats of ‘Kedi,’ Rekindling a ‘Lov...            None
#
#     headline.content_kicker  \
# 0                      None
# 1                      None
# 2                      None
# 3                      None
# 4                      None
# ..                      ...
# 195                    None
# 196                    None
# 197                    None
# 198                    None
# 199                    None
#
#                                headline.print_headline headline.name  \
# 0                               The Attachment Diaries          None
# 1                       What’s Love Got to Do With It?          None
# 2                                 You Can Live Forever          None
# 3                           A Tourist’s  Guide to Love          None
# 4               Intoxicating Love With a Sobering Turn          None
# ..                                                 ...           ...
# 195  Review: A Combustible Pair Find Love in ‘The O...          None
# 196  Review: Love as the World Wars, in ‘The Ottoma...          None
# 197                   It’s Inevitable, Mirth and Taxes          None
# 198                           Everybody Loves Somebody          None
# 199                                               Kedi          None
#
#     headline.seo headline.sub           byline.original  \
# 0           None         None    By Jeannette Catsoulis
# 1           None         None    By Jeannette Catsoulis
# 2           None         None  By Elisabeth Vincentelli
# 3           None         None  By Elisabeth Vincentelli
# 4           None         None         By Manohla Dargis
# ..           ...          ...                       ...
# 195         None         None           By Andy Webster
# 196         None         None        By Neil Genzlinger
# 197         None         None         By Ken Jaworowski
# 198         None         None    By Jeannette Catsoulis
# 199         None         None            By Glenn Kenny
#
#                                          byline.person byline.organization
# 0    [{'firstname': 'Jeannette', 'middlename': None...                None
# 1    [{'firstname': 'Jeannette', 'middlename': None...                None
# 2    [{'firstname': 'Elisabeth', 'middlename': None...                None
# 3    [{'firstname': 'Elisabeth', 'middlename': None...                None
# 4    [{'firstname': 'Manohla', 'middlename': None, ...                None
# ..                                                 ...                 ...
# 195  [{'firstname': 'Andy', 'middlename': None, 'la...                None
# 196  [{'firstname': 'Neil', 'middlename': None, 'la...                None
# 197  [{'firstname': 'Ken', 'middlename': None, 'las...                None
# 198  [{'firstname': 'Jeannette', 'middlename': None...                None
# 199  [{'firstname': 'Glenn', 'middlename': None, 'l...                None
#
# [200 rows x 16 columns]

# %%
# Extract the title from the "headline.main" column and
# save it to a new column "title"
# Title is between unicode characters \u2018 and \u2019. 
# End string should include " Review" to avoid cutting title early
df_reviews["title"] = df_reviews["headline.main"].apply(lambda st: st[st.find("\u2018")+1:st.find("\u2019 Review")])
df_reviews
# Out:
#                                                web_url  \
# 0    https://www.nytimes.com/2023/05/25/movies/the-...
# 1    https://www.nytimes.com/2023/05/04/movies/what...
# 2    https://www.nytimes.com/2023/05/04/movies/you-...
# 3    https://www.nytimes.com/2023/04/21/movies/a-to...
# 4    https://www.nytimes.com/2023/04/20/movies/othe...
# ..                                                 ...
# 195  https://www.nytimes.com/2017/03/09/movies/the-...
# 196  https://www.nytimes.com/2017/03/09/movies/revi...
# 197  https://www.nytimes.com/2017/03/02/movies/love...
# 198  https://www.nytimes.com/2017/02/16/movies/ever...
# 199  https://www.nytimes.com/2017/02/09/movies/kedi...
#
#                                                snippet              source  \
# 0    A gynecologist and her patient form a horrifyi...  The New York Times
# 1    Two childhood friends navigate cultural differ...  The New York Times
# 2    Religion comes between two girls falling in lo...  The New York Times
# 3    Rachael Leigh Cook stars in this bland rom-com...  The New York Times
# 4    A radiant Virginie Efira stars as a Parisian t...  The New York Times
# ..                                                 ...                 ...
# 195  This moody romance stars Tatiana Maslany (“Orp...  The New York Times
# 196  A nurse travels to the Ottoman Empire on the e...  The New York Times
# 197  Josh Kornbluth runs afoul of the Internal Reve...  The New York Times
# 198  A messed-up heroine is asked to choose between...  The New York Times
# 199  This documentary profiles distinctive street c...  The New York Times
#
#                                               keywords  \
# 0    [{'name': 'subject', 'value': 'Movies', 'rank'...
# 1    [{'name': 'subject', 'value': 'Movies', 'rank'...
# 2    [{'name': 'subject', 'value': 'Movies', 'rank'...
# 3    [{'name': 'subject', 'value': 'Movies', 'rank'...
# 4    [{'name': 'subject', 'value': 'Movies', 'rank'...
# ..                                                 ...
# 195  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 196  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 197  [{'name': 'creative_works', 'value': 'Love & T...
# 198  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 199  [{'name': 'creative_works', 'value': 'Kedi (Mo...
#
#                      pub_date  word_count  \
# 0    2023-05-25T11:00:03+0000         295
# 1    2023-05-04T17:16:45+0000         287
# 2    2023-05-04T11:00:08+0000         294
# 3    2023-04-21T07:03:25+0000         276
# 4    2023-04-20T15:35:13+0000         801
# ..                        ...         ...
# 195  2017-03-09T21:54:58+0000         251
# 196  2017-03-09T21:53:12+0000         267
# 197  2017-03-02T21:44:18+0000         246
# 198  2017-02-16T21:45:50+0000         256
# 199  2017-02-09T16:21:39+0000         274
#
#                                          headline.main headline.kicker  \
# 0          ‘The Attachment Diaries’ Review: Love, Sick            None
# 1    Review: ‘What’s Love Got to Do With It?’ Proba...            None
# 2    ‘You Can Live Forever’ Review: Do You Love Me ...            None
# 3    ‘A Tourist’s Guide to Love’ Review: A Wearying...            None
# 4       ‘Other People’s Children’ Review: True Romance   Critic’s pick
# ..                                                 ...             ...
# 195  Review: A Combustible Pair Find Love in ‘The O...            None
# 196  Review: Love as the World Wars, in ‘The Ottoma...            None
# 197  Review: It’s All Mirth and Taxes in ‘Love & Ta...            None
# 198  Review: ‘Everybody Loves Somebody,’ a Rom-Com ...            None
# 199  Review: Cute Cats of ‘Kedi,’ Rekindling a ‘Lov...            None
#
#     headline.content_kicker  \
# 0                      None
# 1                      None
# 2                      None
# 3                      None
# 4                      None
# ..                      ...
# 195                    None
# 196                    None
# 197                    None
# 198                    None
# 199                    None
#
#                                headline.print_headline headline.name  \
# 0                               The Attachment Diaries          None
# 1                       What’s Love Got to Do With It?          None
# 2                                 You Can Live Forever          None
# 3                           A Tourist’s  Guide to Love          None
# 4               Intoxicating Love With a Sobering Turn          None
# ..                                                 ...           ...
# 195  Review: A Combustible Pair Find Love in ‘The O...          None
# 196  Review: Love as the World Wars, in ‘The Ottoma...          None
# 197                   It’s Inevitable, Mirth and Taxes          None
# 198                           Everybody Loves Somebody          None
# 199                                               Kedi          None
#
#     headline.seo headline.sub           byline.original  \
# 0           None         None    By Jeannette Catsoulis
# 1           None         None    By Jeannette Catsoulis
# 2           None         None  By Elisabeth Vincentelli
# 3           None         None  By Elisabeth Vincentelli
# 4           None         None         By Manohla Dargis
# ..           ...          ...                       ...
# 195         None         None           By Andy Webster
# 196         None         None        By Neil Genzlinger
# 197         None         None         By Ken Jaworowski
# 198         None         None    By Jeannette Catsoulis
# 199         None         None            By Glenn Kenny
#
#                                          byline.person byline.organization  \
# 0    [{'firstname': 'Jeannette', 'middlename': None...                None
# 1    [{'firstname': 'Jeannette', 'middlename': None...                None
# 2    [{'firstname': 'Elisabeth', 'middlename': None...                None
# 3    [{'firstname': 'Elisabeth', 'middlename': None...                None
# 4    [{'firstname': 'Manohla', 'middlename': None, ...                None
# ..                                                 ...                 ...
# 195  [{'firstname': 'Andy', 'middlename': None, 'la...                None
# 196  [{'firstname': 'Neil', 'middlename': None, 'la...                None
# 197  [{'firstname': 'Ken', 'middlename': None, 'las...                None
# 198  [{'firstname': 'Jeannette', 'middlename': None...                None
# 199  [{'firstname': 'Glenn', 'middlename': None, 'l...                None
#
#                                              title
# 0                           The Attachment Diaries
# 1    What’s Love Got to Do With It?’ Probably a Lo
# 2                             You Can Live Forever
# 3                        A Tourist’s Guide to Love
# 4                          Other People’s Children
# ..                                             ...
# 195                                 The Other Half
# 196                         The Ottoman Lieutenant
# 197                                   Love & Taxes
# 198  Everybody Loves Somebody,’ a Rom-Com With Bit
# 199              Kedi,’ Rekindling a ‘Love of Life
#
# [200 rows x 17 columns]

# %%
# Extract 'name' and 'value' from items in "keywords" column
def extract_keywords(keyword_list):
    extracted_keywords = ""
    for item in keyword_list:
        print(item)
        # Extract 'name' and 'value'
        keyword = f"{item['name']}: {item['value']};" 
        # Append the keyword item to the extracted_keywords list
        extracted_keywords += keyword
    return extracted_keywords

# Fix the "keywords" column by converting cells from a list to a string    THIS!!!
print(df_reviews)

df_reviews["keywords"] = df_reviews["keywords"].apply(extract_keywords)
# Out:
#                                                web_url  \
# 0    https://www.nytimes.com/2023/05/25/movies/the-...
# 1    https://www.nytimes.com/2023/05/04/movies/what...
# 2    https://www.nytimes.com/2023/05/04/movies/you-...
# 3    https://www.nytimes.com/2023/04/21/movies/a-to...
# 4    https://www.nytimes.com/2023/04/20/movies/othe...
# ..                                                 ...
# 195  https://www.nytimes.com/2017/03/09/movies/the-...
# 196  https://www.nytimes.com/2017/03/09/movies/revi...
# 197  https://www.nytimes.com/2017/03/02/movies/love...
# 198  https://www.nytimes.com/2017/02/16/movies/ever...
# 199  https://www.nytimes.com/2017/02/09/movies/kedi...
#
#                                                snippet              source  \
# 0    A gynecologist and her patient form a horrifyi...  The New York Times
# 1    Two childhood friends navigate cultural differ...  The New York Times
# 2    Religion comes between two girls falling in lo...  The New York Times
# 3    Rachael Leigh Cook stars in this bland rom-com...  The New York Times
# 4    A radiant Virginie Efira stars as a Parisian t...  The New York Times
# ..                                                 ...                 ...
# 195  This moody romance stars Tatiana Maslany (“Orp...  The New York Times
# 196  A nurse travels to the Ottoman Empire on the e...  The New York Times
# 197  Josh Kornbluth runs afoul of the Internal Reve...  The New York Times
# 198  A messed-up heroine is asked to choose between...  The New York Times
# 199  This documentary profiles distinctive street c...  The New York Times
#
#                                               keywords  \
# 0    [{'name': 'subject', 'value': 'Movies', 'rank'...
# 1    [{'name': 'subject', 'value': 'Movies', 'rank'...
# 2    [{'name': 'subject', 'value': 'Movies', 'rank'...
# 3    [{'name': 'subject', 'value': 'Movies', 'rank'...
# 4    [{'name': 'subject', 'value': 'Movies', 'rank'...
# ..                                                 ...
# 195  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 196  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 197  [{'name': 'creative_works', 'value': 'Love & T...
# 198  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 199  [{'name': 'creative_works', 'value': 'Kedi (Mo...
#
#                      pub_date  word_count  \
# 0    2023-05-25T11:00:03+0000         295
# 1    2023-05-04T17:16:45+0000         287
# 2    2023-05-04T11:00:08+0000         294
# 3    2023-04-21T07:03:25+0000         276
# 4    2023-04-20T15:35:13+0000         801
# ..                        ...         ...
# 195  2017-03-09T21:54:58+0000         251
# 196  2017-03-09T21:53:12+0000         267
# 197  2017-03-02T21:44:18+0000         246
# 198  2017-02-16T21:45:50+0000         256
# 199  2017-02-09T16:21:39+0000         274
#
#                                          headline.main headline.kicker  \
# 0          ‘The Attachment Diaries’ Review: Love, Sick            None
# 1    Review: ‘What’s Love Got to Do With It?’ Proba...            None
# 2    ‘You Can Live Forever’ Review: Do You Love Me ...            None
# 3    ‘A Tourist’s Guide to Love’ Review: A Wearying...            None
# 4       ‘Other People’s Children’ Review: True Romance   Critic’s pick
# ..                                                 ...             ...
# 195  Review: A Combustible Pair Find Love in ‘The O...            None
# 196  Review: Love as the World Wars, in ‘The Ottoma...            None
# 197  Review: It’s All Mirth and Taxes in ‘Love & Ta...            None
# 198  Review: ‘Everybody Loves Somebody,’ a Rom-Com ...            None
# 199  Review: Cute Cats of ‘Kedi,’ Rekindling a ‘Lov...            None
#
#     headline.content_kicker  \
# 0                      None
# 1                      None
# 2                      None
# 3                      None
# 4                      None
# ..                      ...
# 195                    None
# 196                    None
# 197                    None
# 198                    None
# 199                    None
#
#                                headline.print_headline headline.name  \
# 0                               The Attachment Diaries          None
# 1                       What’s Love Got to Do With It?          None
# 2                                 You Can Live Forever          None
# 3                           A Tourist’s  Guide to Love          None
# 4               Intoxicating Love With a Sobering Turn          None
# ..                                                 ...           ...
# 195  Review: A Combustible Pair Find Love in ‘The O...          None
# 196  Review: Love as the World Wars, in ‘The Ottoma...          None
# 197                   It’s Inevitable, Mirth and Taxes          None
# 198                           Everybody Loves Somebody          None
# 199                                               Kedi          None
#
#     headline.seo headline.sub           byline.original  \
# 0           None         None    By Jeannette Catsoulis
# 1           None         None    By Jeannette Catsoulis
# 2           None         None  By Elisabeth Vincentelli
# 3           None         None  By Elisabeth Vincentelli
# 4           None         None         By Manohla Dargis
# ..           ...          ...                       ...
# 195         None         None           By Andy Webster
# 196         None         None        By Neil Genzlinger
# 197         None         None         By Ken Jaworowski
# 198         None         None    By Jeannette Catsoulis
# 199         None         None            By Glenn Kenny
#
#                                          byline.person byline.organization  \
# 0    [{'firstname': 'Jeannette', 'middlename': None...                None
# 1    [{'firstname': 'Jeannette', 'middlename': None...                None
# 2    [{'firstname': 'Elisabeth', 'middlename': None...                None
# 3    [{'firstname': 'Elisabeth', 'middlename': None...                None
# 4    [{'firstname': 'Manohla', 'middlename': None, ...                None
# ..                                                 ...                 ...
# 195  [{'firstname': 'Andy', 'middlename': None, 'la...                None
# 196  [{'firstname': 'Neil', 'middlename': None, 'la...                None
# 197  [{'firstname': 'Ken', 'middlename': None, 'las...                None
# 198  [{'firstname': 'Jeannette', 'middlename': None...                None
# 199  [{'firstname': 'Glenn', 'middlename': None, 'l...                None
#
#                                              title
# 0                           The Attachment Diaries
# 1    What’s Love Got to Do With It?’ Probably a Lo
# 2                             You Can Live Forever
# 3                        A Tourist’s Guide to Love
# 4                          Other People’s Children
# ..                                             ...
# 195                                 The Other Half
# 196                         The Ottoman Lieutenant
# 197                                   Love & Taxes
# 198  Everybody Loves Somebody,’ a Rom-Com With Bit
# 199              Kedi,’ Rekindling a ‘Love of Life
#
# [200 rows x 17 columns]
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'creative_works', 'value': 'The Attachment Diaries (Movie)', 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'Diment, Valentin Javier', 'rank': 3, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'persons', 'value': 'Kapur, Shekhar', 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'James, Lily', 'rank': 3, 'major': 'N'}
# {'name': 'persons', 'value': 'Azmi, Shabana', 'rank': 4, 'major': 'N'}
# {'name': 'persons', 'value': 'Thompson, Emma', 'rank': 5, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'creative_works', 'value': 'You Can Live Forever (Movie)', 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'Slutsky, Mark', 'rank': 3, 'major': 'N'}
# {'name': 'persons', 'value': 'Watts, Sarah (Film Director)', 'rank': 4, 'major': 'N'}
# {'name': 'persons', 'value': "O'Driscoll, Anwen", 'rank': 5, 'major': 'N'}
# {'name': 'persons', 'value': 'Laporte, June (Actor)', 'rank': 6, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'creative_works', 'value': "A Tourist's Guide to Love (Movie)", 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'Tsuchida, Steven', 'rank': 3, 'major': 'N'}
# {'name': 'persons', 'value': 'Cook, Rachael Leigh', 'rank': 4, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'persons', 'value': 'Zlotowski, Rebecca', 'rank': 2, 'major': 'N'}
# {'name': 'creative_works', 'value': "Other People's Children (Movie)", 'rank': 3, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'persons', 'value': 'Bracey, Luke (1989- )', 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'Liu, Simu', 'rank': 3, 'major': 'N'}
# {'name': 'persons', 'value': 'Reid, Taylor Jenkins', 'rank': 4, 'major': 'N'}
# {'name': 'persons', 'value': 'Soo, Phillipa', 'rank': 5, 'major': 'N'}
# {'name': 'persons', 'value': 'Fickman, Andy', 'rank': 6, 'major': 'N'}
# {'name': 'creative_works', 'value': 'One True Loves (Movie)', 'rank': 7, 'major': 'N'}
# {'name': 'subject', 'value': 'Documentary Films and Programs', 'rank': 1, 'major': 'N'}
# {'name': 'creative_works', 'value': 'The Lost Weekend: A Love Story (Movie)', 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'Pang, May', 'rank': 3, 'major': 'N'}
# {'name': 'persons', 'value': 'Lennon, John', 'rank': 4, 'major': 'N'}
# {'name': 'persons', 'value': 'Ono, Yoko', 'rank': 5, 'major': 'N'}
# {'name': 'persons', 'value': 'Brandstein, Eve', 'rank': 6, 'major': 'N'}
# {'name': 'persons', 'value': 'Kaufman, Richard S (Filmmaker)', 'rank': 7, 'major': 'N'}
# {'name': 'persons', 'value': 'Samuels, Stuart (Filmmaker)', 'rank': 8, 'major': 'N'}
# {'name': 'subject', 'value': 'Content Type: Personal Profile', 'rank': 9, 'major': 'N'}
# {'name': 'subject', 'value': 'Pop and Rock Music', 'rank': 10, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'creative_works', 'value': 'A Thousand and One (Movie)', 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'Rockwell, AV (Film Director)', 'rank': 3, 'major': 'N'}
# {'name': 'persons', 'value': 'Taylor, Teyana (1990- )', 'rank': 4, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'creative_works', 'value': 'Your Place or Mine (Movie)', 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'Witherspoon, Reese', 'rank': 3, 'major': 'N'}
# {'name': 'persons', 'value': 'Kutcher, Ashton', 'rank': 4, 'major': 'N'}
# {'name': 'persons', 'value': 'McKenna, Aline Brosh', 'rank': 5, 'major': 'N'}
# {'name': 'subject', 'value': 'Documentary Films and Programs', 'rank': 1, 'major': 'N'}
# {'name': 'subject', 'value': 'Fentanyl', 'rank': 2, 'major': 'N'}
# {'name': 'subject', 'value': 'Drug Abuse and Traffic', 'rank': 3, 'major': 'N'}
# {'name': 'subject', 'value': 'Volunteers and Community Service', 'rank': 4, 'major': 'N'}
# {'name': 'creative_works', 'value': 'Love in the Time of Fentanyl (Movie)', 'rank': 5, 'major': 'N'}
# {'name': 'persons', 'value': 'Askey, Colin', 'rank': 6, 'major': 'N'}
# {'name': 'glocations', 'value': 'Vancouver (British Columbia)', 'rank': 7, 'major': 'N'}
# {'name': 'organizations', 'value': 'Overdose Prevention Society', 'rank': 8, 'major': 'N'}
# {'name': 'subject', 'value': 'Documentary Films and Programs', 'rank': 1, 'major': 'N'}
# {'name': 'persons', 'value': 'Anderson, Pamela (1967- )', 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'White, Ryan (Filmmaker)', 'rank': 3, 'major': 'N'}
# {'name': 'creative_works', 'value': 'Pamela, a Love Story (Movie)', 'rank': 4, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'creative_works', 'value': 'In From the Side (Movie)', 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'Carter, Matt (Filmmaker)', 'rank': 3, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'creative_works', 'value': 'After Love (2020) (Movie)', 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'Khan, Aleem', 'rank': 3, 'major': 'N'}
# {'name': 'persons', 'value': 'Scanlan, Joanna (1961- )', 'rank': 4, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'persons', 'value': 'Simon, Carla', 'rank': 2, 'major': 'N'}
# {'name': 'creative_works', 'value': 'Alcarras (Movie)', 'rank': 3, 'major': 'N'}
# {'name': 'subject', 'value': 'Documentary Films and Programs', 'rank': 1, 'major': 'N'}
# {'name': 'persons', 'value': 'Gertten, Magnus', 'rank': 2, 'major': 'N'}
# {'name': 'creative_works', 'value': 'Nelly & Nadine (Movie)', 'rank': 3, 'major': 'N'}
# {'name': 'subject', 'value': 'Content Type: Personal Profile', 'rank': 4, 'major': 'N'}
# {'name': 'subject', 'value': 'Holocaust and the Nazi Era', 'rank': 5, 'major': 'N'}
# {'name': 'subject', 'value': 'World War II (1939-45)', 'rank': 6, 'major': 'N'}
# {'name': 'subject', 'value': 'Women and Girls', 'rank': 7, 'major': 'N'}
# {'name': 'subject', 'value': 'Homosexuality and Bisexuality', 'rank': 8, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'creative_works', 'value': "Lady Chatterley's Lover (Movie)", 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'Corrin, Emma (1995- )', 'rank': 3, 'major': 'N'}
# {'name': 'persons', 'value': 'De Clermont-Tonnerre, Laure', 'rank': 4, 'major': 'N'}
# {'name': 'persons', 'value': 'Lawrence, D H', 'rank': 5, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'persons', 'value': 'Ne-Yo', 'rank': 2, 'major': 'N'}
# {'name': 'creative_works', 'value': 'The Sound of Christmas (Movie)', 'rank': 3, 'major': 'N'}
# {'name': 'persons', 'value': 'Mattison, Booker T', 'rank': 4, 'major': 'N'}
# {'name': 'persons', 'value': 'McNeill, Serayah', 'rank': 5, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'creative_works', 'value': 'The Inspection (Movie)', 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'Bratton, Elegance', 'rank': 3, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'creative_works', 'value': 'Bones and All (Movie)', 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'Guadagnino, Luca', 'rank': 3, 'major': 'N'}
# {'name': 'persons', 'value': 'Chalamet, Timothee (1995- )', 'rank': 4, 'major': 'N'}
# {'name': 'persons', 'value': 'Russell, Taylor (1994- )', 'rank': 5, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'creative_works', 'value': 'My Policeman (Movie)', 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'Grandage, Michael', 'rank': 3, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'creative_works', 'value': 'About Fate (Movie)', 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'Vaysberg, Marius', 'rank': 3, 'major': 'N'}
# {'name': 'persons', 'value': 'Mann, Thomas (1991- )', 'rank': 4, 'major': 'N'}
# {'name': 'persons', 'value': 'Roberts, Emma (1991- )', 'rank': 5, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'persons', 'value': 'Bourdeaut, Olivier', 'rank': 2, 'major': 'N'}
# {'name': 'creative_works', 'value': 'Waiting for Bojangles (Movie)', 'rank': 3, 'major': 'N'}
# {'name': 'persons', 'value': 'Roinsard, Regis', 'rank': 4, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'persons', 'value': 'Oswalt, Patton', 'rank': 2, 'major': 'N'}
# {'name': 'creative_works', 'value': 'I Love My Dad (Movie)', 'rank': 3, 'major': 'N'}
# {'name': 'persons', 'value': 'Morosini, James', 'rank': 4, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'creative_works', 'value': 'A Love Song (Movie)', 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'Walker-Silverman, Max', 'rank': 3, 'major': 'N'}
# {'name': 'persons', 'value': 'Dickey, Dale (Actor)', 'rank': 4, 'major': 'N'}
# {'name': 'persons', 'value': 'STUDI, WES', 'rank': 5, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'persons', 'value': 'Holmes, Katie', 'rank': 2, 'major': 'N'}
# {'name': 'creative_works', 'value': 'Alone Together (Movie)', 'rank': 3, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'creative_works', 'value': 'Art of Love (Movie)', 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'Kaplan, Betty (Film Director)', 'rank': 3, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'creative_works', 'value': 'The Wheel (Movie)', 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'Pink, Steve', 'rank': 3, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'organizations', 'value': 'Marvel Studios', 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'Bale, Christian', 'rank': 3, 'major': 'N'}
# {'name': 'persons', 'value': 'Crowe, Russell', 'rank': 4, 'major': 'N'}
# {'name': 'persons', 'value': 'Hemsworth, Chris', 'rank': 5, 'major': 'N'}
# {'name': 'persons', 'value': 'Waititi, Taika', 'rank': 6, 'major': 'N'}
# {'name': 'persons', 'value': 'Thompson, Tessa', 'rank': 7, 'major': 'N'}
# {'name': 'persons', 'value': 'Portman, Natalie', 'rank': 8, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'persons', 'value': 'Denis, Claire', 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'Binoche, Juliette', 'rank': 3, 'major': 'N'}
# {'name': 'persons', 'value': 'Lindon, Vincent', 'rank': 4, 'major': 'N'}
# {'name': 'creative_works', 'value': 'Both Sides of the Blade (Movie)', 'rank': 5, 'major': 'N'}
# {'name': 'subject', 'value': 'Documentary Films and Programs', 'rank': 1, 'major': 'N'}
# {'name': 'subject', 'value': 'Volcanoes', 'rank': 2, 'major': 'N'}
# {'name': 'creative_works', 'value': 'Fire of Love (Movie)', 'rank': 3, 'major': 'N'}
# {'name': 'subject', 'value': 'Content Type: Personal Profile', 'rank': 4, 'major': 'N'}
# {'name': 'subject', 'value': 'Deaths (Fatalities)', 'rank': 5, 'major': 'N'}
# {'name': 'persons', 'value': 'Dosa, Sara', 'rank': 6, 'major': 'N'}
# {'name': 'persons', 'value': 'Krafft, Maurice (1946-91)', 'rank': 7, 'major': 'N'}
# {'name': 'persons', 'value': 'Krafft, Katia (1942-91)', 'rank': 8, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'creative_works', 'value': 'Love & Gelato (Movie)', 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'Camp, Brandon (1971- )', 'rank': 3, 'major': 'N'}
# {'name': 'subject', 'value': 'Documentary Films and Programs', 'rank': 1, 'major': 'N'}
# {'name': 'subject', 'value': 'Gospel Music', 'rank': 2, 'major': 'N'}
# {'name': 'creative_works', 'value': 'Stay Prayed Up (Movie)', 'rank': 3, 'major': 'N'}
# {'name': 'subject', 'value': 'Content Type: Personal Profile', 'rank': 4, 'major': 'N'}
# {'name': 'persons', 'value': 'Perry, Lena Mae', 'rank': 5, 'major': 'N'}
# {'name': 'organizations', 'value': 'Branchettes (Music Group)', 'rank': 6, 'major': 'N'}
# {'name': 'persons', 'value': 'Anderson, DL (Filmmaker)', 'rank': 7, 'major': 'N'}
# {'name': 'persons', 'value': 'Durning, Matthew', 'rank': 8, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'persons', 'value': 'Davies, Terence', 'rank': 2, 'major': 'N'}
# {'name': 'creative_works', 'value': 'Benediction (Movie)', 'rank': 3, 'major': 'N'}
# {'name': 'persons', 'value': 'Lowden, Jack (1990- )', 'rank': 4, 'major': 'N'}
# {'name': 'subject', 'value': 'Poetry and Poets', 'rank': 5, 'major': 'N'}
# {'name': 'persons', 'value': 'Sassoon, Siegfried', 'rank': 6, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'persons', 'value': 'Rehmeier, Adam', 'rank': 2, 'major': 'N'}
# {'name': 'creative_works', 'value': 'Dinner in America (Book)', 'rank': 3, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'creative_works', 'value': 'In A New York Minute (Movie)', 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'Ximan Li', 'rank': 3, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'persons', 'value': 'Bourgeois-Tacquet, Charline', 'rank': 2, 'major': 'N'}
# {'name': 'creative_works', 'value': 'Anais in Love (Movie)', 'rank': 3, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'persons', 'value': 'Marceau, Sophie', 'rank': 2, 'major': 'N'}
# {'name': 'creative_works', 'value': 'I Love America (Movie)', 'rank': 3, 'major': 'N'}
# {'name': 'persons', 'value': 'Azuelos, Lisa', 'rank': 4, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'creative_works', 'value': 'See You Then (Movie)', 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'Walker, Mari', 'rank': 3, 'major': 'N'}
# {'name': 'subject', 'value': 'Documentary Films and Programs', 'rank': 1, 'major': 'N'}
# {'name': 'subject', 'value': 'Women and Girls', 'rank': 2, 'major': 'N'}
# {'name': 'subject', 'value': 'Dancing', 'rank': 3, 'major': 'N'}
# {'name': 'subject', 'value': 'Bars and Nightclubs', 'rank': 4, 'major': 'N'}
# {'name': 'subject', 'value': 'Labor and Jobs', 'rank': 5, 'major': 'N'}
# {'name': 'subject', 'value': 'Content Type: Personal Profile', 'rank': 6, 'major': 'N'}
# {'name': 'glocations', 'value': 'Mexico City (Mexico)', 'rank': 7, 'major': 'N'}
# {'name': 'glocations', 'value': 'Mexico', 'rank': 8, 'major': 'N'}
# {'name': 'creative_works', 'value': 'La Mami (Movie)', 'rank': 9, 'major': 'N'}
# {'name': 'persons', 'value': 'Garvin, Laura Herrero', 'rank': 10, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'organizations', 'value': 'MUBI Inc', 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'Hui, Ann', 'rank': 3, 'major': 'N'}
# {'name': 'persons', 'value': 'Peng, Eddie (1982- )', 'rank': 4, 'major': 'N'}
# {'name': 'glocations', 'value': 'Hong Kong', 'rank': 5, 'major': 'N'}
# {'name': 'creative_works', 'value': 'Love After Love (Movie)', 'rank': 6, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'creative_works', 'value': 'Deep Water (Movie)', 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'Affleck, Ben', 'rank': 3, 'major': 'N'}
# {'name': 'persons', 'value': 'Lyne, Adrian', 'rank': 4, 'major': 'N'}
# {'name': 'persons', 'value': 'de Armas, Ana', 'rank': 5, 'major': 'N'}
# {'name': 'subject', 'value': 'Documentary Films and Programs', 'rank': 1, 'major': 'N'}
# {'name': 'persons', 'value': 'Ball, Lucille', 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'ARNAZ, DESI', 'rank': 3, 'major': 'N'}
# {'name': 'persons', 'value': 'Poehler, Amy', 'rank': 4, 'major': 'N'}
# {'name': 'creative_works', 'value': 'Lucy and Desi (Movie)', 'rank': 5, 'major': 'N'}
# {'name': 'subject', 'value': 'Television', 'rank': 6, 'major': 'N'}
# {'name': 'subject', 'value': 'Actors and Actresses', 'rank': 7, 'major': 'N'}
# {'name': 'subject', 'value': 'Content Type: Personal Profile', 'rank': 8, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'creative_works', 'value': 'Cyrano (Movie)', 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'Wright, Joe', 'rank': 3, 'major': 'N'}
# {'name': 'persons', 'value': 'Dinklage, Peter', 'rank': 4, 'major': 'N'}
# {'name': 'persons', 'value': 'Bennett, Haley', 'rank': 5, 'major': 'N'}
# {'name': 'persons', 'value': 'Harrison, Kelvin Jr', 'rank': 6, 'major': 'N'}
# {'name': 'persons', 'value': 'Berninger, Matt', 'rank': 7, 'major': 'N'}
# {'name': 'persons', 'value': 'Besser, Carin', 'rank': 8, 'major': 'N'}
# {'name': 'persons', 'value': 'Dessner, Aaron', 'rank': 9, 'major': 'N'}
# {'name': 'persons', 'value': 'Schmidt, Erica (1975- )', 'rank': 10, 'major': 'N'}
# {'name': 'organizations', 'value': 'National, The (Music Group)', 'rank': 11, 'major': 'N'}
# {'name': 'persons', 'value': 'King, Joey', 'rank': 1, 'major': 'N'}
# {'name': 'persons', 'value': 'Allen, Kyle (1994- )', 'rank': 2, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 3, 'major': 'N'}
# {'name': 'persons', 'value': 'Posin, Arie', 'rank': 4, 'major': 'N'}
# {'name': 'creative_works', 'value': 'The In Between (Movie)', 'rank': 5, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'persons', 'value': 'Claflin, Sam', 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'Cal y Mayor, Analeine', 'rank': 3, 'major': 'N'}
# {'name': 'creative_works', 'value': 'Book of Love (Movie)', 'rank': 4, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'persons', 'value': 'Haroun, Mahamat-Saleh', 'rank': 2, 'major': 'N'}
# {'name': 'creative_works', 'value': 'Lingui, the Sacred Bonds (Movie)', 'rank': 3, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'creative_works', 'value': 'The Pink Cloud (Movie)', 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'Gerbase, Iuli', 'rank': 3, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'creative_works', 'value': 'A Journal for Jordan (Movie)', 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'Washington, Denzel', 'rank': 3, 'major': 'N'}
# {'name': 'persons', 'value': 'Jordan, Michael B', 'rank': 4, 'major': 'N'}
# {'name': 'persons', 'value': 'Adams, Chante', 'rank': 5, 'major': 'N'}
# {'name': 'subject', 'value': 'Books and Literature', 'rank': 6, 'major': 'N'}
# {'name': 'creative_works', 'value': 'A Journal for Jordan: A Story of Love and Honor (Book)', 'rank': 7, 'major': 'N'}
# {'name': 'persons', 'value': 'Canedy, Dana', 'rank': 8, 'major': 'N'}
# {'name': 'subject', 'value': 'Black People', 'rank': 9, 'major': 'N'}
# {'name': 'subject', 'value': 'Blacks', 'rank': 10, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'subject', 'value': 'Theater', 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'Alvarez, David (1994- )', 'rank': 3, 'major': 'N'}
# {'name': 'persons', 'value': 'Bernstein, Leonard', 'rank': 4, 'major': 'N'}
# {'name': 'persons', 'value': 'DeBose, Ariana', 'rank': 5, 'major': 'N'}
# {'name': 'persons', 'value': 'Kushner, Tony', 'rank': 6, 'major': 'N'}
# {'name': 'persons', 'value': 'Laurents, Arthur', 'rank': 7, 'major': 'N'}
# {'name': 'persons', 'value': 'Peck, Justin', 'rank': 8, 'major': 'N'}
# {'name': 'persons', 'value': 'Robbins, Jerome', 'rank': 9, 'major': 'N'}
# {'name': 'persons', 'value': 'Sondheim, Stephen', 'rank': 10, 'major': 'N'}
# {'name': 'persons', 'value': 'Spielberg, Steven', 'rank': 11, 'major': 'N'}
# {'name': 'persons', 'value': 'Tesori, Jeanine', 'rank': 12, 'major': 'N'}
# {'name': 'glocations', 'value': 'New York City', 'rank': 13, 'major': 'N'}
# {'name': 'creative_works', 'value': 'West Side Story (2021) (Movie)', 'rank': 14, 'major': 'N'}
# {'name': 'subject', 'value': 'Documentary Films and Programs', 'rank': 1, 'major': 'N'}
# {'name': 'subject', 'value': 'Basketball', 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'Menkin, Dani', 'rank': 3, 'major': 'N'}
# {'name': 'persons', 'value': 'Perry, Aulcie', 'rank': 4, 'major': 'N'}
# {'name': 'creative_works', 'value': 'Aulcie (Movie)', 'rank': 5, 'major': 'N'}
# {'name': 'glocations', 'value': 'Israel', 'rank': 6, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'persons', 'value': 'Coppola, Eleanor', 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'Arquette, Rosanna', 'rank': 3, 'major': 'N'}
# {'name': 'persons', 'value': 'Shepherd, Cybill', 'rank': 4, 'major': 'N'}
# {'name': 'persons', 'value': 'Wilson, Rita', 'rank': 5, 'major': 'N'}
# {'name': 'creative_works', 'value': 'Love Is Love Is Love (Movie)', 'rank': 6, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'creative_works', 'value': 'Love Hard (Movie)', 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'Jimenez, Hernan', 'rank': 3, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'persons', 'value': 'Bergman, Ingmar', 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'Roth, Tim', 'rank': 3, 'major': 'N'}
# {'name': 'persons', 'value': 'Wasikowska, Mia', 'rank': 4, 'major': 'N'}
# {'name': 'persons', 'value': 'Hansen-Love, Mia', 'rank': 5, 'major': 'N'}
# {'name': 'creative_works', 'value': 'Bergman Island (Movie)', 'rank': 6, 'major': 'N'}
# {'name': 'persons', 'value': 'Krieps, Vicky', 'rank': 7, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'persons', 'value': 'Dorman, Michael (1981- )', 'rank': 2, 'major': 'N'}
# {'name': 'creative_works', 'value': 'Hard Luck Love Song (Movie)', 'rank': 3, 'major': 'N'}
# {'name': 'persons', 'value': 'Bush, Sophia (1982- )', 'rank': 4, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'persons', 'value': 'Sudeikis, Jason', 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'Lilly, Evangeline (1979- )', 'rank': 3, 'major': 'N'}
# {'name': 'persons', 'value': 'Keshales, Aharon', 'rank': 4, 'major': 'N'}
# {'name': 'creative_works', 'value': 'South of Heaven (Movie)', 'rank': 5, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'persons', 'value': 'Kurosawa, Kiyoshi', 'rank': 2, 'major': 'N'}
# {'name': 'creative_works', 'value': 'Wife of a Spy (Movie)', 'rank': 3, 'major': 'N'}
# {'name': 'subject', 'value': 'Documentary Films and Programs', 'rank': 1, 'major': 'N'}
# {'name': 'subject', 'value': 'Music', 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'Eilish, Billie', 'rank': 3, 'major': 'N'}
# {'name': 'persons', 'value': 'Rodriguez, Robert', 'rank': 4, 'major': 'N'}
# {'name': 'creative_works', 'value': 'Happier Than Ever: A Love Letter to Los Angeles (Movie)', 'rank': 5, 'major': 'N'}
# {'name': 'persons', 'value': 'Osborne, Patrick (Film Director)', 'rank': 6, 'major': 'N'}
# {'name': 'glocations', 'value': 'Los Angeles (Calif)', 'rank': 7, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'creative_works', 'value': 'Together (Movie)', 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'Daldry, Stephen', 'rank': 3, 'major': 'N'}
# {'name': 'persons', 'value': 'McAvoy, James', 'rank': 4, 'major': 'N'}
# {'name': 'persons', 'value': 'Horgan, Sharon (1970- )', 'rank': 5, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'persons', 'value': 'Carax, Leos', 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'Cotillard, Marion', 'rank': 3, 'major': 'N'}
# {'name': 'persons', 'value': 'Driver, Adam', 'rank': 4, 'major': 'N'}
# {'name': 'persons', 'value': 'Mael, Ron', 'rank': 5, 'major': 'N'}
# {'name': 'persons', 'value': 'Mael, Russell', 'rank': 6, 'major': 'N'}
# {'name': 'creative_works', 'value': 'Annette (Movie)', 'rank': 7, 'major': 'N'}
# {'name': 'organizations', 'value': 'Sparks (Music Group)', 'rank': 8, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'persons', 'value': 'Milian, Christina', 'rank': 2, 'major': 'N'}
# {'name': 'creative_works', 'value': 'Resort to Love (Movie)', 'rank': 3, 'major': 'N'}
# {'name': 'persons', 'value': 'Tsuchida, Steven', 'rank': 4, 'major': 'N'}
# {'name': 'subject', 'value': 'Documentary Films and Programs', 'rank': 1, 'major': 'N'}
# {'name': 'persons', 'value': 'Price, Garret', 'rank': 2, 'major': 'N'}
# {'name': 'creative_works', 'value': 'Woodstock 99: Peace, Love and Rage (Movie)', 'rank': 3, 'major': 'N'}
# {'name': 'subject', 'value': 'Woodstock Music Festivals', 'rank': 4, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'persons', 'value': 'Jacquot, Benoit', 'rank': 2, 'major': 'N'}
# {'name': 'creative_works', 'value': 'Casanova, Last Love (Movie)', 'rank': 3, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'creative_works', 'value': 'Running Against the Wind (Movie)', 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'Weyl, Jan Philipp', 'rank': 3, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'persons', 'value': 'Haas, Shira', 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'Pribar, Ruthy', 'rank': 3, 'major': 'N'}
# {'name': 'persons', 'value': 'Yiv, Alena', 'rank': 4, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'persons', 'value': 'Petzold, Christian', 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'Rogowski, Franz', 'rank': 3, 'major': 'N'}
# {'name': 'creative_works', 'value': 'Undine (Movie)', 'rank': 4, 'major': 'N'}
# {'name': 'persons', 'value': 'Beer, Paula (1995- )', 'rank': 5, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'creative_works', 'value': 'This Town (Movie)', 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'White, David (Director)', 'rank': 3, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'creative_works', 'value': 'Tu Me Manques (Movie)', 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'Martinez, Oscar (1949- )', 'rank': 3, 'major': 'N'}
# {'name': 'persons', 'value': 'Barbosa, Fernando (Actor)', 'rank': 4, 'major': 'N'}
# {'name': 'persons', 'value': 'Bellott, Rodrigo', 'rank': 5, 'major': 'N'}
# {'name': 'glocations', 'value': 'Bolivia', 'rank': 6, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'persons', 'value': 'Papadimitropoulos, Argyris', 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'Stan, Sebastian', 'rank': 3, 'major': 'N'}
# {'name': 'persons', 'value': 'Gough, Denise (1980- )', 'rank': 4, 'major': 'N'}
# {'name': 'creative_works', 'value': 'Monday (Movie)', 'rank': 5, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'creative_works', 'value': 'Ride or Die (Movie)', 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'Hiroki, Ryuichi', 'rank': 3, 'major': 'N'}
# {'name': 'subject', 'value': 'Documentary Films and Programs', 'rank': 1, 'major': 'N'}
# {'name': 'creative_works', 'value': 'Future People: The Family of Donor 5114 (Movie)', 'rank': 2, 'major': 'N'}
# {'name': 'subject', 'value': 'ARTIFICIAL INSEMINATION', 'rank': 3, 'major': 'N'}
# {'name': 'subject', 'value': 'Children and Childhood', 'rank': 4, 'major': 'N'}
# {'name': 'persons', 'value': 'Rothman, Michael (Filmmaker)', 'rank': 5, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'creative_works', 'value': 'Luz (Movie)', 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'Garcia, Jon (1979- )', 'rank': 3, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'creative_works', 'value': 'Happily (Movie)', 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'Grabinski, BenDavid', 'rank': 3, 'major': 'N'}
# {'name': 'subject', 'value': 'Documentary Films and Programs', 'rank': 1, 'major': 'N'}
# {'name': 'subject', 'value': 'Rap and Hip-Hop', 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'DuVernay, Ava', 'rank': 3, 'major': 'N'}
# {'name': 'subject', 'value': 'Black People', 'rank': 4, 'major': 'N'}
# {'name': 'subject', 'value': 'Blacks', 'rank': 5, 'major': 'N'}
# {'name': 'glocations', 'value': 'California', 'rank': 6, 'major': 'N'}
# {'name': 'glocations', 'value': 'Los Angeles (Calif)', 'rank': 7, 'major': 'N'}
# {'name': 'creative_works', 'value': 'This Is the Life (Movie)', 'rank': 8, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'persons', 'value': 'Condor, Lana', 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'Fimognari, Michael', 'rank': 3, 'major': 'N'}
# {'name': 'persons', 'value': 'Centineo, Noah', 'rank': 4, 'major': 'N'}
# {'name': 'creative_works', 'value': 'To All the Boys: Always and Forever (Movie)', 'rank': 5, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'creative_works', 'value': 'Young Hearts (Movie)', 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'Sherman, Sarah (Film Director)', 'rank': 3, 'major': 'N'}
# {'name': 'persons', 'value': 'Sherman, Zachary Ray (1984- )', 'rank': 4, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'creative_works', 'value': 'Little Fish (Movie)', 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'Hartigan, Chad', 'rank': 3, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'persons', 'value': 'Sukowa, Barbara', 'rank': 2, 'major': 'N'}
# {'name': 'creative_works', 'value': 'Two of Us (Movie)', 'rank': 3, 'major': 'N'}
# {'name': 'persons', 'value': 'Meneghetti, Filippo', 'rank': 4, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'creative_works', 'value': 'Atlantis (Movie)', 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'Vasyanovych, Valentyn', 'rank': 3, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'creative_works', 'value': 'Preparations to Be Together for an Unknown Period of Time (Movie)', 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'Horvat, Lili', 'rank': 3, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'glocations', 'value': 'Taiwan', 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'Liu, Patrick (Filmmaker)', 'rank': 3, 'major': 'N'}
# {'name': 'creative_works', 'value': 'Your Name Engraved Herein (Movie)', 'rank': 4, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'persons', 'value': 'Asomugha, Nnamdi', 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'King, Aja Naomi', 'rank': 3, 'major': 'N'}
# {'name': 'persons', 'value': 'Longoria, Eva', 'rank': 4, 'major': 'N'}
# {'name': 'persons', 'value': 'Thompson, Tessa', 'rank': 5, 'major': 'N'}
# {'name': 'glocations', 'value': 'Harlem (Manhattan, NY)', 'rank': 6, 'major': 'N'}
# {'name': 'creative_works', 'value': "Sylvie's Love (Movie)", 'rank': 7, 'major': 'N'}
# {'name': 'persons', 'value': 'Ashe, Eugene', 'rank': 8, 'major': 'N'}
# {'name': 'subject', 'value': 'Pop and Rock Music', 'rank': 1, 'major': 'N'}
# {'name': 'subject', 'value': 'Documentary Films and Programs', 'rank': 2, 'major': 'N'}
# {'name': 'creative_works', 'value': 'Ariana Grande: Excuse Me, I Love You (Movie)', 'rank': 3, 'major': 'N'}
# {'name': 'persons', 'value': 'Grande, Ariana', 'rank': 4, 'major': 'N'}
# {'name': 'persons', 'value': 'Dugdale, Paul (1980- )', 'rank': 5, 'major': 'N'}
# {'name': 'subject', 'value': 'Content Type: Personal Profile', 'rank': 6, 'major': 'N'}
# {'name': 'subject', 'value': 'Documentary Films and Programs', 'rank': 1, 'major': 'N'}
# {'name': 'subject', 'value': 'Art', 'rank': 2, 'major': 'N'}
# {'name': 'creative_works', 'value': 'Museum Town (Movie)', 'rank': 3, 'major': 'N'}
# {'name': 'persons', 'value': 'Trainer, Jennifer', 'rank': 4, 'major': 'N'}
# {'name': 'organizations', 'value': 'Massachusetts Museum of Contemporary Art', 'rank': 5, 'major': 'N'}
# {'name': 'subject', 'value': 'Museums', 'rank': 6, 'major': 'N'}
# {'name': 'glocations', 'value': 'North Adams (Mass)', 'rank': 7, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'persons', 'value': 'Shanley, John Patrick', 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'Blunt, Emily', 'rank': 3, 'major': 'N'}
# {'name': 'persons', 'value': 'Dornan, Jamie', 'rank': 4, 'major': 'N'}
# {'name': 'creative_works', 'value': 'Outside Mullingar (Play)', 'rank': 5, 'major': 'N'}
# {'name': 'creative_works', 'value': 'Wild Mountain Thyme (Movie)', 'rank': 6, 'major': 'N'}
# {'name': 'subject', 'value': 'Documentary Films and Programs', 'rank': 1, 'major': 'N'}
# {'name': 'creative_works', 'value': 'My Psychedelic Love Story (Movie)', 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'Harcourt-Smith, Joanna (1946-2020)', 'rank': 3, 'major': 'N'}
# {'name': 'persons', 'value': 'Morris, Errol', 'rank': 4, 'major': 'N'}
# {'name': 'subject', 'value': 'LSD (Lysergic Acid Diethylamide)', 'rank': 5, 'major': 'N'}
# {'name': 'subject', 'value': 'Content Type: Personal Profile', 'rank': 6, 'major': 'N'}
# {'name': 'subject', 'value': 'Documentary Films and Programs', 'rank': 1, 'major': 'N'}
# {'name': 'subject', 'value': 'Rap and Hip-Hop', 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'Gandhi, Vikram', 'rank': 3, 'major': 'N'}
# {'name': 'persons', 'value': '6ix9ine (Rapper)', 'rank': 4, 'major': 'N'}
# {'name': 'creative_works', 'value': '69: The Saga of Danny Hernandez (Movie)', 'rank': 5, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'persons', 'value': 'Ronan, Saoirse', 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'Winslet, Kate', 'rank': 3, 'major': 'N'}
# {'name': 'persons', 'value': 'Lee, Francis (1969- )', 'rank': 4, 'major': 'N'}
# {'name': 'creative_works', 'value': 'Ammonite (Movie)', 'rank': 5, 'major': 'N'}
# {'name': 'persons', 'value': 'Matthews, Michael (Film Director)', 'rank': 1, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 2, 'major': 'N'}
# {'name': 'creative_works', 'value': 'Love and Monsters (Movie)', 'rank': 3, 'major': 'N'}
# {'name': 'creative_works', 'value': 'Dick Johnson Is Dead (Movie)', 'rank': 1, 'major': 'N'}
# {'name': 'subject', 'value': 'Documentary Films and Programs', 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'Johnson, Kirsten (1965- )', 'rank': 3, 'major': 'N'}
# {'name': 'creative_works', 'value': 'Cameraperson (Movie)', 'rank': 4, 'major': 'N'}
# {'name': 'subject', 'value': 'Death and Dying', 'rank': 5, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'persons', 'value': 'Cook, Rachael Leigh', 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'Wayans, Damon Jr', 'rank': 3, 'major': 'N'}
# {'name': 'persons', 'value': 'Johnson, Mark Steven', 'rank': 4, 'major': 'N'}
# {'name': 'creative_works', 'value': 'Love, Guaranteed (Movie)', 'rank': 5, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'persons', 'value': 'Carson, Sofia (1993- )', 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'Down, Elissa (1975- )', 'rank': 3, 'major': 'N'}
# {'name': 'creative_works', 'value': 'Feel the Beat (Movie)', 'rank': 4, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'creative_works', 'value': 'Babyteeth (Movie)', 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'Murphy, Shannon (Film Director)', 'rank': 3, 'major': 'N'}
# {'name': 'persons', 'value': 'Scanlen, Eliza', 'rank': 4, 'major': 'N'}
# {'name': 'persons', 'value': 'Wallace, Toby (1996- )', 'rank': 5, 'major': 'N'}
# {'name': 'subject', 'value': 'Documentary Films and Programs', 'rank': 1, 'major': 'N'}
# {'name': 'subject', 'value': 'Scripps National Spelling Bee', 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'Rega, Sam', 'rank': 3, 'major': 'N'}
# {'name': 'creative_works', 'value': 'Spelling the Dream (Movie)', 'rank': 4, 'major': 'N'}
# {'name': 'subject', 'value': 'Spelling', 'rank': 5, 'major': 'N'}
# {'name': 'organizations', 'value': 'Netflix Inc', 'rank': 6, 'major': 'N'}
# {'name': 'subject', 'value': 'Documentary Films and Programs', 'rank': 1, 'major': 'N'}
# {'name': 'subject', 'value': 'Homosexuality and Bisexuality', 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'Bolan, Chris (Filmmaker)', 'rank': 3, 'major': 'N'}
# {'name': 'creative_works', 'value': 'A Secret Love (Movie)', 'rank': 4, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'creative_works', 'value': 'Love Wedding Repeat (Movie)', 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'Craig, Dean (1974- )', 'rank': 3, 'major': 'N'}
# {'name': 'persons', 'value': 'Claflin, Sam', 'rank': 4, 'major': 'N'}
# {'name': 'persons', 'value': 'Munn, Olivia', 'rank': 5, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'creative_works', 'value': 'Almost Love (Movie)', 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'Doyle, Mike (1972- )', 'rank': 3, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'persons', 'value': 'Bening, Annette', 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'Nighy, Bill', 'rank': 3, 'major': 'N'}
# {'name': 'persons', 'value': 'Nicholson, William (1948- )', 'rank': 4, 'major': 'N'}
# {'name': 'creative_works', 'value': 'Hope Gap (Movie)', 'rank': 5, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'creative_works', 'value': 'All the Bright Places (Movie)', 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'Haley, Brett', 'rank': 3, 'major': 'N'}
# {'name': 'persons', 'value': 'Fanning, Elle', 'rank': 4, 'major': 'N'}
# {'name': 'persons', 'value': 'Smith, Justice (1995- )', 'rank': 5, 'major': 'N'}
# {'name': 'organizations', 'value': 'Netflix Inc', 'rank': 6, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'creative_works', 'value': 'The Photograph (Movie)', 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'Meghie, Stella', 'rank': 3, 'major': 'N'}
# {'name': 'persons', 'value': 'Rae, Issa', 'rank': 4, 'major': 'N'}
# {'name': 'persons', 'value': 'Stanfield, Lakeith', 'rank': 5, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'creative_works', 'value': 'You Go to My Head (Movie)', 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'de Clercq, Dimitri', 'rank': 3, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'creative_works', 'value': 'Ordinary Love (Movie)', 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'Neeson, Liam', 'rank': 3, 'major': 'N'}
# {'name': 'persons', 'value': 'Manville, Lesley', 'rank': 4, 'major': 'N'}
# {'name': 'persons', 'value': "D'Sa, Lisa Barros", 'rank': 5, 'major': 'N'}
# {'name': 'persons', 'value': 'Leyburn, Glenn', 'rank': 6, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'persons', 'value': 'Condor, Lana', 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'Centineo, Noah', 'rank': 3, 'major': 'N'}
# {'name': 'creative_works', 'value': 'To All the Boys: PS I Still Love You (Movie)', 'rank': 4, 'major': 'N'}
# {'name': 'persons', 'value': 'Fimognari, Michael', 'rank': 5, 'major': 'N'}
# {'name': 'subject', 'value': 'Documentary Films and Programs', 'rank': 1, 'major': 'N'}
# {'name': 'subject', 'value': 'Giraffes', 'rank': 2, 'major': 'N'}
# {'name': 'creative_works', 'value': 'The Woman Who Loves Giraffes (Movie)', 'rank': 3, 'major': 'N'}
# {'name': 'persons', 'value': 'Dagg, Anne Innis', 'rank': 4, 'major': 'N'}
# {'name': 'persons', 'value': 'Reid, Alison (Filmmaker)', 'rank': 5, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'creative_works', 'value': 'Queen & Slim (Movie)', 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'Matsoukas, Melina', 'rank': 3, 'major': 'N'}
# {'name': 'persons', 'value': 'Waithe, Lena', 'rank': 4, 'major': 'N'}
# {'name': 'persons', 'value': 'Kaluuya, Daniel', 'rank': 5, 'major': 'N'}
# {'name': 'persons', 'value': 'Turner-Smith, Jodie', 'rank': 6, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'persons', 'value': 'Baumbach, Noah', 'rank': 2, 'major': 'N'}
# {'name': 'creative_works', 'value': 'Marriage Story (Movie)', 'rank': 3, 'major': 'N'}
# {'name': 'persons', 'value': 'Driver, Adam', 'rank': 4, 'major': 'N'}
# {'name': 'persons', 'value': 'Johansson, Scarlett', 'rank': 5, 'major': 'N'}
# {'name': 'persons', 'value': 'ALDA, ALAN', 'rank': 6, 'major': 'N'}
# {'name': 'persons', 'value': 'Dern, Laura', 'rank': 7, 'major': 'N'}
# ...
# {'name': 'persons', 'value': 'Dignam, Erin', 'rank': 7, 'major': 'N'}
# {'name': 'subject', 'value': 'Books and Literature', 'rank': 8, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'creative_works', 'value': 'Love After Love (Movie)', 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'Harbaugh, Russ', 'rank': 3, 'major': 'N'}
# {'name': 'persons', 'value': 'MacDowell, Andie', 'rank': 4, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'creative_works', 'value': 'Outside In (Movie)', 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'Shelton, Lynn', 'rank': 3, 'major': 'N'}
# {'name': 'persons', 'value': 'Duplass, Jay', 'rank': 4, 'major': 'N'}
# {'name': 'persons', 'value': 'Falco, Edie', 'rank': 5, 'major': 'N'}
# {'name': 'persons', 'value': 'Dever, Kaitlyn', 'rank': 6, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'creative_works', 'value': 'Love, Simon (Movie)', 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'Berlanti, Greg', 'rank': 3, 'major': 'N'}
# {'name': 'persons', 'value': 'Robinson, Nick (1995- )', 'rank': 4, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'creative_works', 'value': 'Keep the Change (Movie)', 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'Israel, Rachel', 'rank': 3, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'creative_works', 'value': 'The Party (Movie)', 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'Potter, Sally', 'rank': 3, 'major': 'N'}
# {'name': 'persons', 'value': 'Spall, Timothy', 'rank': 4, 'major': 'N'}
# {'name': 'persons', 'value': 'Scott Thomas, Kristin', 'rank': 5, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'glocations', 'value': 'Vietnam', 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'Nguyen, Derek', 'rank': 3, 'major': 'N'}
# {'name': 'creative_works', 'value': 'The Housemaid (Movie)', 'rank': 4, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'creative_works', 'value': 'Forever My Girl (Movie)', 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'Wolf, Bethany Ashton', 'rank': 3, 'major': 'N'}
# {'name': 'creative_works', 'value': 'Kangaroo: A Love-Hate Story (Movie)', 'rank': 1, 'major': 'N'}
# {'name': 'subject', 'value': 'Kangaroos', 'rank': 2, 'major': 'N'}
# {'name': 'subject', 'value': 'Animal Abuse, Rights and Welfare', 'rank': 3, 'major': 'N'}
# {'name': 'persons', 'value': 'McIntyre Clere, Kate', 'rank': 4, 'major': 'N'}
# {'name': 'persons', 'value': 'McIntyre, Mick', 'rank': 5, 'major': 'N'}
# {'name': 'subject', 'value': 'Documentary Films and Programs', 'rank': 6, 'major': 'N'}
# {'name': 'glocations', 'value': 'Australia', 'rank': 7, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'creative_works', 'value': 'Lover for a Day (Movie)', 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'Garrel, Philippe', 'rank': 3, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'persons', 'value': 'Feng Xiaogang', 'rank': 2, 'major': 'N'}
# {'name': 'creative_works', 'value': 'Youth (Movie)', 'rank': 3, 'major': 'N'}
# {'name': 'creative_works', 'value': 'Killing for Love (Movie)', 'rank': 1, 'major': 'N'}
# {'name': 'persons', 'value': 'Soering, Jens', 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'Haysom, Elizabeth', 'rank': 3, 'major': 'N'}
# {'name': 'persons', 'value': 'Vetter, Marcus (1967- )', 'rank': 4, 'major': 'N'}
# {'name': 'persons', 'value': 'Steinberger, Karin', 'rank': 5, 'major': 'N'}
# {'name': 'subject', 'value': 'Documentary Films and Programs', 'rank': 6, 'major': 'N'}
# {'name': 'subject', 'value': 'Murders, Attempted Murders and Homicides', 'rank': 7, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'creative_works', 'value': 'The Shape of Water (Movie)', 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'Del Toro, Guillermo', 'rank': 3, 'major': 'N'}
# {'name': 'persons', 'value': 'Spencer, Octavia', 'rank': 4, 'major': 'N'}
# {'name': 'persons', 'value': 'Shannon, Michael', 'rank': 5, 'major': 'N'}
# {'name': 'persons', 'value': 'Hawkins, Sally', 'rank': 6, 'major': 'N'}
# {'name': 'persons', 'value': 'Jones, Doug (1960- )', 'rank': 7, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'subject', 'value': 'Rap and Hip-Hop', 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'RZA', 'rank': 3, 'major': 'N'}
# {'name': 'persons', 'value': 'Banks, Azealia', 'rank': 4, 'major': 'N'}
# {'name': 'creative_works', 'value': 'Love Beats Rhymes (Movie)', 'rank': 5, 'major': 'N'}
# {'name': 'subject', 'value': 'Documentary Films and Programs', 'rank': 1, 'major': 'N'}
# {'name': 'glocations', 'value': 'Cuba', 'rank': 2, 'major': 'N'}
# {'name': 'creative_works', 'value': 'Cuba and the Cameraman (Movie)', 'rank': 3, 'major': 'N'}
# {'name': 'persons', 'value': 'ALPERT, JON', 'rank': 4, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'creative_works', 'value': 'On the Beach at Night Alone (Movie)', 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'Hong Sang-soo', 'rank': 3, 'major': 'N'}
# {'name': 'persons', 'value': 'Kim Min-hee', 'rank': 4, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'creative_works', 'value': 'Thelma (Movie)', 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'Trier, Joachim', 'rank': 3, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'creative_works', 'value': 'Hello Again (Movie)', 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'Gustafson, Tom', 'rank': 3, 'major': 'N'}
# {'name': 'persons', 'value': 'Jackson, Cheyenne', 'rank': 4, 'major': 'N'}
# {'name': 'persons', 'value': 'McDonald, Audra', 'rank': 5, 'major': 'N'}
# {'name': 'persons', 'value': 'Willis, Rumer (1988- )', 'rank': 6, 'major': 'N'}
# {'name': 'persons', 'value': 'LaChiusa, Michael John', 'rank': 7, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'creative_works', 'value': 'It Happened in L.A. (Movie)', 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'Morgan, Michelle (Filmmaker)', 'rank': 3, 'major': 'N'}
# {'name': 'persons', 'value': 'Hemingway, Dree (1987- )', 'rank': 4, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'creative_works', 'value': "God's Own Country (Movie)", 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'Lee, Francis (1969- )', 'rank': 3, 'major': 'N'}
# {'name': 'persons', 'value': "O'Connor, Josh (Actor)", 'rank': 4, 'major': 'N'}
# {'name': 'persons', 'value': 'Secareanu, Alec', 'rank': 5, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'creative_works', 'value': 'The Mountain Between Us (Movie)', 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'ABU-ASSAD, HANY', 'rank': 3, 'major': 'N'}
# {'name': 'persons', 'value': 'Elba, Idris', 'rank': 4, 'major': 'N'}
# {'name': 'persons', 'value': 'Winslet, Kate', 'rank': 5, 'major': 'N'}
# {'name': 'creative_works', 'value': 'Dina (Movie)', 'rank': 1, 'major': 'N'}
# {'name': 'subject', 'value': 'Documentary Films and Programs', 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'Sickles, Dan (Film Director)', 'rank': 3, 'major': 'N'}
# {'name': 'persons', 'value': 'Santini, Antonio (Film Director)', 'rank': 4, 'major': 'N'}
# {'name': 'subject', 'value': 'Autism', 'rank': 5, 'major': 'N'}
# {'name': 'subject', 'value': 'Dating and Relationships', 'rank': 6, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'creative_works', 'value': 'In Search of Fellini (Movie)', 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'Cartwright, Nancy', 'rank': 3, 'major': 'N'}
# {'name': 'persons', 'value': 'Solo, Ksenia', 'rank': 4, 'major': 'N'}
# {'name': 'persons', 'value': 'Lexton, Taron', 'rank': 5, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'creative_works', 'value': 'Woodpeckers (Movie)', 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'Cabral, Jose Maria', 'rank': 3, 'major': 'N'}
# {'name': 'persons', 'value': 'Jean, Jean (Actor)', 'rank': 4, 'major': 'N'}
# {'name': 'persons', 'value': 'Rodriguez, Judith (1985- )', 'rank': 5, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'persons', 'value': 'Bell, Lake', 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'Reiser, Paul', 'rank': 3, 'major': 'N'}
# {'name': 'creative_works', 'value': "I Do... Until I Don't (Movie)", 'rank': 4, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'creative_works', 'value': 'Tales of an Immoral Couple (Movie)', 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'Caro, Manolo', 'rank': 3, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'creative_works', 'value': 'After Love (Movie)', 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'Lafosse, Joachim', 'rank': 3, 'major': 'N'}
# {'name': 'persons', 'value': 'Bejo, Berenice', 'rank': 4, 'major': 'N'}
# {'name': 'persons', 'value': 'Kahn, Cedric', 'rank': 5, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'creative_works', 'value': 'The Last Face (Movie)', 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'Penn, Sean', 'rank': 3, 'major': 'N'}
# {'name': 'persons', 'value': 'Bardem, Javier', 'rank': 4, 'major': 'N'}
# {'name': 'persons', 'value': 'Theron, Charlize', 'rank': 5, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'creative_works', 'value': 'Women Who Kill (Movie)', 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'Jungermann, Ingrid (1977- )', 'rank': 3, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'creative_works', 'value': 'False Confessions (Movie)', 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'Bondy, Luc', 'rank': 3, 'major': 'N'}
# {'name': 'persons', 'value': 'Huppert, Isabelle', 'rank': 4, 'major': 'N'}
# {'name': 'persons', 'value': 'Garrel, Louis', 'rank': 5, 'major': 'N'}
# {'name': 'subject', 'value': 'Documentary Films and Programs', 'rank': 1, 'major': 'N'}
# {'name': 'persons', 'value': 'Tavernier, Bertrand', 'rank': 2, 'major': 'N'}
# {'name': 'creative_works', 'value': 'My Journey Through French Cinema (Movie)', 'rank': 3, 'major': 'N'}
# {'name': 'glocations', 'value': 'France', 'rank': 4, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'creative_works', 'value': 'The Big Sick (Movie)', 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'Nanjiani, Kumail', 'rank': 3, 'major': 'N'}
# {'name': 'persons', 'value': 'Gordon, Emily V', 'rank': 4, 'major': 'N'}
# {'name': 'persons', 'value': 'Kazan, Zoe', 'rank': 5, 'major': 'N'}
# {'name': 'persons', 'value': 'Showalter, Michael', 'rank': 6, 'major': 'N'}
# {'name': 'creative_works', 'value': 'Lost in Paris (Movie)', 'rank': 1, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'Abel, Dominique', 'rank': 3, 'major': 'N'}
# {'name': 'persons', 'value': 'Gordon, Fiona', 'rank': 4, 'major': 'N'}
# {'name': 'persons', 'value': 'Riva, Emmanuelle', 'rank': 5, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'creative_works', 'value': 'Vincent N Roxxy (Movie)', 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'Kravitz, Zoe', 'rank': 3, 'major': 'N'}
# {'name': 'persons', 'value': 'Schultz, Gary Michael', 'rank': 4, 'major': 'N'}
# {'name': 'persons', 'value': 'Hirsch, Emile', 'rank': 5, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'creative_works', 'value': 'Everything, Everything (Movie)', 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'Meghie, Stella', 'rank': 3, 'major': 'N'}
# {'name': 'persons', 'value': 'Stenberg, Amandla (1998- )', 'rank': 4, 'major': 'N'}
# {'name': 'persons', 'value': 'Robinson, Nick (1995- )', 'rank': 5, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'creative_works', 'value': 'Hounds of Love (Movie)', 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'Young, Ben (Film Director)', 'rank': 3, 'major': 'N'}
# {'name': 'creative_works', 'value': 'Harold and Lillian: A Hollywood Love Story (Movie)', 'rank': 1, 'major': 'N'}
# {'name': 'persons', 'value': 'Raim, Daniel', 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'Michelson, Harold', 'rank': 3, 'major': 'N'}
# {'name': 'persons', 'value': 'Michelson, Lillian', 'rank': 4, 'major': 'N'}
# {'name': 'subject', 'value': 'Documentary Films and Programs', 'rank': 5, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 6, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'creative_works', 'value': 'The Happiest Day in the Life of Olli Maki (Movie)', 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'Kuosmanen, Juho', 'rank': 3, 'major': 'N'}
# {'name': 'persons', 'value': 'Lahti, Jarkko', 'rank': 4, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'creative_works', 'value': 'The Promise (Movie)', 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'George, Terry', 'rank': 3, 'major': 'N'}
# {'name': 'persons', 'value': 'Bale, Christian', 'rank': 4, 'major': 'N'}
# {'name': 'persons', 'value': 'Isaac, Oscar', 'rank': 5, 'major': 'N'}
# {'name': 'persons', 'value': 'Le Bon, Charlotte', 'rank': 6, 'major': 'N'}
# {'name': 'creative_works', 'value': 'Frantz (Movie)', 'rank': 1, 'major': 'N'}
# {'name': 'persons', 'value': 'Niney, Pierre', 'rank': 2, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 3, 'major': 'N'}
# {'name': 'persons', 'value': 'Lubitsch, Ernst', 'rank': 4, 'major': 'N'}
# {'name': 'persons', 'value': 'Ozon, Francois', 'rank': 5, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'creative_works', 'value': 'The Other Half (Movie)', 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'Maslany, Tatiana', 'rank': 3, 'major': 'N'}
# {'name': 'persons', 'value': 'Cullen, Tom (1985- )', 'rank': 4, 'major': 'N'}
# {'name': 'persons', 'value': 'Klein, Joey (Film Director)', 'rank': 5, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'creative_works', 'value': 'The Ottoman Lieutenant (Movie)', 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'Ruben, Joseph', 'rank': 3, 'major': 'N'}
# {'name': 'persons', 'value': 'Hartnett, Josh', 'rank': 4, 'major': 'N'}
# {'name': 'persons', 'value': 'Stockwell, Jeff (1958- )', 'rank': 5, 'major': 'N'}
# {'name': 'persons', 'value': 'Hilmar, Hera', 'rank': 6, 'major': 'N'}
# {'name': 'persons', 'value': 'Huisman, Michiel', 'rank': 7, 'major': 'N'}
# {'name': 'creative_works', 'value': 'Love & Taxes (Movie)', 'rank': 1, 'major': 'N'}
# {'name': 'persons', 'value': 'Kornbluth, Jacob', 'rank': 2, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 3, 'major': 'N'}
# {'name': 'persons', 'value': 'Kornbluth, Josh', 'rank': 4, 'major': 'N'}
# {'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}
# {'name': 'creative_works', 'value': 'Everybody Loves Somebody (Movie)', 'rank': 2, 'major': 'N'}
# {'name': 'persons', 'value': 'Aguilar Mastretta, Catalina', 'rank': 3, 'major': 'N'}
# {'name': 'persons', 'value': 'Souza, Karla (1985- )', 'rank': 4, 'major': 'N'}
# {'name': 'creative_works', 'value': 'Kedi (Movie)', 'rank': 1, 'major': 'N'}
# {'name': 'subject', 'value': 'Documentary Films and Programs', 'rank': 2, 'major': 'N'}
# {'name': 'subject', 'value': 'Cats', 'rank': 3, 'major': 'N'}
# {'name': 'glocations', 'value': 'Istanbul (Turkey)', 'rank': 4, 'major': 'N'}
# {'name': 'persons', 'value': 'Torun, Ceyda', 'rank': 5, 'major': 'N'}

# %%
# Create a list from the "title" column using to_list()
# These titles will be used in the query for The Movie Database
titles = df_reviews["title"].to_list()
titles
# Out:
# ['The Attachment Diaries',
#  'What’s Love Got to Do With It?’ Probably a Lo',
#  'You Can Live Forever',
#  'A Tourist’s Guide to Love',
#  'Other People’s Children',
#  'One True Loves',
#  'The Lost Weekend: A Love Story',
#  'A Thousand and One',
#  'Your Place or Mine',
#  'Love in the Time of Fentanyl',
#  'Pamela, a Love Story',
#  'In From the Side',
#  'After Love',
#  'Alcarràs',
#  'Nelly & Nadine',
#  'Lady Chatterley’s Lover',
#  'The Sound of Christmas',
#  'The Inspection',
#  'Bones and All',
#  'My Policeman',
#  'About Fate',
#  'Waiting for Bojangles',
#  'I Love My Dad',
#  'A Love Song',
#  'Alone Together',
#  'Art of Love',
#  'The Wheel',
#  'Thor: Love and Thunder',
#  'Both Sides of the Blade',
#  'Fire of Love',
#  'Love & Gelato',
#  'Stay Prayed Up',
#  'Benediction',
#  'Dinner in America',
#  'In a New York Minute',
#  'Anaïs in Love',
#  'I Love America',
#  'See You Then',
#  'La Mami',
#  'Love After Love',
#  'Deep Water',
#  'Lucy and Desi',
#  'Cyrano',
#  'The In Between',
#  'Book of Love',
#  'Lingui, the Sacred Bonds',
#  'The Pink Cloud',
#  'A Journal for Jordan',
#  'West Side Story',
#  'Aulcie',
#  'Love Is Love Is Love',
#  'Love Hard',
#  'Bergman Island',
#  'Hard Luck Love Song',
#  'South of Heaven',
#  'Wife of a Spy',
#  'Happier Than Ever',
#  'Together',
#  'Annette',
#  'Resort to Love',
#  'Woodstock 99: Peace, Love and Rage',
#  'Casanova, Last Love',
#  'Running Against the Wind',
#  'Asia',
#  'Undine',
#  'This Town',
#  'Tu Me Manques',
#  'Monday',
#  'Ride or Die',
#  'Future People',
#  'Luz',
#  'Happily',
#  'This Is the Life',
#  'To All the Boys: Always and Forever',
#  'Young Hearts',
#  'Little Fish',
#  'Two of Us',
#  'Atlantis',
#  'Preparations to Be Together',
#  'Your Name Engraved Herein',
#  'Sylvie’s Love',
#  'Ariana Grande: Excuse Me, I Love You',
#  'Museum Town',
#  'Wild Mountain Thyme',
#  'My Psychedelic Love Story',
#  '69: The Saga of Danny Hernandez',
#  'Ammonite',
#  'Love and Monsters',
#  'Dick Johnson Is Dead',
#  'Love, Guaranteed',
#  'Feel the Beat',
#  'Babyteeth',
#  'Spelling the Dream',
#  'A Secret Love',
#  'Love Wedding Repeat',
#  'Almost Love',
#  'Hope Gap',
#  'All the Bright Places',
#  'The Photograph',
#  'You Go to My Head',
#  'Ordinary Love',
#  'To All the Boys: P.S. I Still Love You',
#  'The Woman Who Loves Giraffes',
#  'Queen & Slim',
#  'Marriage Story',
#  'Cyrano, My Love',
#  'Pretenders',
#  'First Love',
#  'Loro',
#  'Falling Inn Love',
#  'Hot Air',
#  'Love, Antosha',
#  'Leto',
#  'The Tomorrow Man',
#  'Asako I & II',
#  'The Sun Is Also a Star',
#  'Shéhérazade',
#  'Long Shot',
#  'Clara',
#  'Kalank',
#  'Rafiki',
#  'Diane',
#  'Five Feet Apart',
#  'Ash Is Purest White',
#  'Gloria Bell',
#  'Black Mother',
#  'The Hole in the Ground',
#  'How to Train Your Dragon: The Hidden World',
#  'A Tuba to Cuba',
#  'Fighting With My Family',
#  'Sorry Angel',
#  'Berlin, I Love You',
#  'Untogether',
#  'Cold War',
#  'If Beale Street Could Talk',
#  'Asher',
#  'The Party’s Just Beginning',
#  'The Great Pretender',
#  'Sicilian Ghost Story',
#  'The New Romantic',
#  'Pimp',
#  'In a Relationship',
#  'They’ll Love Me When I’m Dead’ Documents Orson Welles’s Last Fil',
#  'Burning,’ Love Ignites a Divided Worl',
#  'After Everything,’ a Young Love Blooms in Crisi',
#  'Quincy’ Captures a Lifelong Love Affair With Musi',
#  'Love, Gilda,’ a Portrait of a Brief and Brilliant Caree',
#  'Tea With the Dames,’ Four Legends Dish on Acting and Lov',
#  'Bel Canto,’ Music Is the Food of Love and Rebellio',
#  'The Citizen,’ an Immigrant Picks a Bad Time to Fall in Lov',
#  'Love, Cecil,’ an Aesthete Ahead of His Tim',
#  'How to Talk to Girls at Parties',
#  'Rogers Park,’ Life and Love in a Chicago Neighborhoo',
#  'Love & Bananas,’ Uncovering the Plight of the Asian Elephan',
#  'Godard Mon Amour',
#  'Submergence,’ a Love Story Sunk by Geopolitic',
#  'Love After Love,’ an Unflinching Look at Extended Grie',
#  'Outside In',
#  'Love, Simon,’ a Glossy Teen Romance, the Hero Has a Secre',
#  'Keep the Change,’ Two People With Autism Find Lov',
#  'The Party',
#  'The Housemaid,’ Twisted Love and Angry Ghosts in Vietna',
#  'Forever My Girl,’ a Romance Resumes After a Long Brea',
#  'Kangaroo: A Love-Hate Story’ Exposes a Wildlife Massacr',
#  'Lover for a Day',
#  'Youth,’ the People’s Dance Troupe, in Love and Wa',
#  'Killing for Love’ Revisits a Virginia Murder Cas',
#  'The Shape of Water’ Is Altogether Wonderfu',
#  'Love Beats Rhymes,’ a Hip-Hop Artist Transformed by Poetr',
#  'Cuba and the Cameraman’ Lavishes Love on a Country … and Castr',
#  'On the Beach at Night Alone’ Zooms in on a Love Affai',
#  'Thelma,’ a Woman in Love Can Burn Down the Worl',
#  'Hello Again,’ a Movie Musical Ode to Love and Lust Over Decade',
#  'It Happened in L.A.,’ All That Questing After Lov',
#  'God’s Own Country',
#  'The Mountain Between Us',
#  'Dina,’ a Differently Abled Love Stor',
#  'In Search of Fellini',
#  'Woodpeckers,’ a Tale of Love and Agonizing Penal Confinemen',
#  'I Do ... Until I Don’t,’ Love and Loathing in Florid',
#  'Tales of an Immoral Couple’: Love Means Having to Grow U',
#  'After Love’ and Regretting Every Momen',
#  'The Last Face',
#  'Women Who Kill,’ and May Be in Love With On',
#  'False Confessions,’ the Play’s Not Quite the Thin',
#  'Review: Those Movies, Himself — Bertrand Tavernier’s Tour of French Cinem',
#  'The Big Sick,’ Comedy Is Hard, Love Harde',
#  'Lost in Paris',
#  'Vincent N Roxxy,’ Love Is in the Air, N So Is Fea',
#  'Everything, Everything’ Pits Love Against Diseas',
#  'Hounds of Love’ Is Tense and Deadly Down Unde',
#  'Harold and Lillian’ Introduces a Hollywood Power Coupl',
#  'The Happiest Day in the Life of Olli Maki,’ Love and Life on the Rope',
#  'The Promise’ Finds a Love Triangle in Constantinopl',
#  'Frantz,’ a Mysterious Frenchman and the Wounds of Wa',
#  'The Other Half',
#  'The Ottoman Lieutenant',
#  'Love & Taxes',
#  'Everybody Loves Somebody,’ a Rom-Com With Bit',
#  'Kedi,’ Rekindling a ‘Love of Life']

# %% [markdown]
# ### Access The Movie Database API

# %%
# Prepare The Movie Database query
url = "https://api.themoviedb.org/3/search/movie?query="
tmdb_key_string = "&api_key=" + tmdb_api_key

# %%
# Create an empty list to store the results
tmdb_movies_list = []

# Create a request counter to sleep the requests after a multiple
# of 50 requests
counter = 1

# Loop through the titles
for n in titles:
    
    # Check if we need to sleep before making a request
    if counter % 50 == 0:
        time.sleep(1)
        # Add 1 to the request counter
    counter = counter + 1        
    
    # Perform a "GET" request for The Movie Database
    

    # Include a try clause to search for the full movie details.
    # Use the except clause to print out a statement if a movie
    # is not found.

        # Get movie id


        # Make a request for a the full movie details


        # Execute "GET" request with url

        
        # Extract the genre names into a list


        # Extract the spoken_languages' English name into a list


        # Extract the production_countries' name into a list


        # Add the relevant data to a dictionary and
        # append it to the tmdb_movies_list list

        
        # Print out the title that was found
# Out:
# Found The Attachment Diaries
# What’s Love Got to Do With It?’ Probably a Lo not found.
# Found You Can Live Forever
# Found A Tourist’s Guide to Love
# Found Other People’s Children
# Found One True Loves
# Found The Lost Weekend: A Love Story
# Found A Thousand and One
# Found Your Place or Mine
# Found Love in the Time of Fentanyl
# Found Pamela, a Love Story
# Found In From the Side
# Found After Love
# Found Alcarràs
# Found Nelly & Nadine
# Found Lady Chatterley’s Lover
# Found The Sound of Christmas
# Found The Inspection
# Found Bones and All
# Found My Policeman
# Found About Fate
# Found Waiting for Bojangles
# Found I Love My Dad
# Found A Love Song
# Found Alone Together
# Found Art of Love
# Found The Wheel
# Found Thor: Love and Thunder
# Found Both Sides of the Blade
# Found Fire of Love
# Found Love & Gelato
# Found Stay Prayed Up
# Found Benediction
# Found Dinner in America
# Found In a New York Minute
# Found Anaïs in Love
# Found I Love America
# Found See You Then
# Found La Mami
# Found Love After Love
# Found Deep Water
# Found Lucy and Desi
# Found Cyrano
# Found The In Between
# Found Book of Love
# Found Lingui, the Sacred Bonds
# Found The Pink Cloud
# Found A Journal for Jordan
# Found West Side Story
# Sleeping at 50 requests
# Found Aulcie
# Found Love Is Love Is Love
# Found Love Hard
# Found Bergman Island
# Found Hard Luck Love Song
# Found South of Heaven
# Found Wife of a Spy
# Found Happier Than Ever
# Found Together
# Found Annette
# Found Resort to Love
# Found Woodstock 99: Peace, Love and Rage
# Found Casanova, Last Love
# Found Running Against the Wind
# Found Asia
# Found Undine
# Found This Town
# Found Tu Me Manques
# Found Monday
# Found Ride or Die
# Found Future People
# Found Luz
# Found Happily
# Found This Is the Life
# Found To All the Boys: Always and Forever
# Found Young Hearts
# Found Little Fish
# Found Two of Us
# Found Atlantis
# Found Preparations to Be Together
# Found Your Name Engraved Herein
# Found Sylvie’s Love
# Found Ariana Grande: Excuse Me, I Love You
# Found Museum Town
# Found Wild Mountain Thyme
# Found My Psychedelic Love Story
# Found 69: The Saga of Danny Hernandez
# Found Ammonite
# Found Love and Monsters
# Found Dick Johnson Is Dead
# Found Love, Guaranteed
# Found Feel the Beat
# Found Babyteeth
# Found Spelling the Dream
# Found A Secret Love
# Found Love Wedding Repeat
# Found Almost Love
# Found Hope Gap
# Found All the Bright Places
# Found The Photograph
# Sleeping at 100 requests
# Found You Go to My Head
# Found Ordinary Love
# Found To All the Boys: P.S. I Still Love You
# Found The Woman Who Loves Giraffes
# Found Queen & Slim
# Found Marriage Story
# Found Cyrano, My Love
# Found Pretenders
# Found First Love
# Found Loro
# Found Falling Inn Love
# Found Hot Air
# Found Love, Antosha
# Found Leto
# Found The Tomorrow Man
# Found Asako I & II
# Found The Sun Is Also a Star
# Found Shéhérazade
# Found Long Shot
# Found Clara
# Found Kalank
# Found Rafiki
# Found Diane
# Found Five Feet Apart
# Found Ash Is Purest White
# Found Gloria Bell
# Found Black Mother
# Found The Hole in the Ground
# Found How to Train Your Dragon: The Hidden World
# Found A Tuba to Cuba
# Found Fighting With My Family
# Found Sorry Angel
# Found Berlin, I Love You
# Found Untogether
# Found Cold War
# Found If Beale Street Could Talk
# Found Asher
# Found The Party’s Just Beginning
# Found The Great Pretender
# Found Sicilian Ghost Story
# Found The New Romantic
# Found Pimp
# Found In a Relationship
# They’ll Love Me When I’m Dead’ Documents Orson Welles’s Last Fil not found.
# Burning,’ Love Ignites a Divided Worl not found.
# After Everything,’ a Young Love Blooms in Crisi not found.
# Quincy’ Captures a Lifelong Love Affair With Musi not found.
# Love, Gilda,’ a Portrait of a Brief and Brilliant Caree not found.
# Tea With the Dames,’ Four Legends Dish on Acting and Lov not found.
# Bel Canto,’ Music Is the Food of Love and Rebellio not found.
# Sleeping at 150 requests
# The Citizen,’ an Immigrant Picks a Bad Time to Fall in Lov not found.
# Love, Cecil,’ an Aesthete Ahead of His Tim not found.
# Found How to Talk to Girls at Parties
# Rogers Park,’ Life and Love in a Chicago Neighborhoo not found.
# Found Love & Bananas,’ Uncovering the Plight of the Asian Elephan
# Found Godard Mon Amour
# Submergence,’ a Love Story Sunk by Geopolitic not found.
# Love After Love,’ an Unflinching Look at Extended Grie not found.
# Found Outside In
# Love, Simon,’ a Glossy Teen Romance, the Hero Has a Secre not found.
# Keep the Change,’ Two People With Autism Find Lov not found.
# Found The Party
# The Housemaid,’ Twisted Love and Angry Ghosts in Vietna not found.
# Forever My Girl,’ a Romance Resumes After a Long Brea not found.
# Kangaroo: A Love-Hate Story’ Exposes a Wildlife Massacr not found.
# Found Lover for a Day
# Youth,’ the People’s Dance Troupe, in Love and Wa not found.
# Killing for Love’ Revisits a Virginia Murder Cas not found.
# The Shape of Water’ Is Altogether Wonderfu not found.
# Love Beats Rhymes,’ a Hip-Hop Artist Transformed by Poetr not found.
# Cuba and the Cameraman’ Lavishes Love on a Country … and Castr not found.
# On the Beach at Night Alone’ Zooms in on a Love Affai not found.
# Thelma,’ a Woman in Love Can Burn Down the Worl not found.
# Hello Again,’ a Movie Musical Ode to Love and Lust Over Decade not found.
# It Happened in L.A.,’ All That Questing After Lov not found.
# Found God’s Own Country
# Found The Mountain Between Us
# Dina,’ a Differently Abled Love Stor not found.
# Found In Search of Fellini
# Woodpeckers,’ a Tale of Love and Agonizing Penal Confinemen not found.
# I Do ... Until I Don’t,’ Love and Loathing in Florid not found.
# Tales of an Immoral Couple’: Love Means Having to Grow U not found.
# After Love’ and Regretting Every Momen not found.
# Found The Last Face
# Women Who Kill,’ and May Be in Love With On not found.
# False Confessions,’ the Play’s Not Quite the Thin not found.
# Review: Those Movies, Himself — Bertrand Tavernier’s Tour of French Cinem not found.
# The Big Sick,’ Comedy Is Hard, Love Harde not found.
# Found Lost in Paris
# Vincent N Roxxy,’ Love Is in the Air, N So Is Fea not found.
# Everything, Everything’ Pits Love Against Diseas not found.
# Hounds of Love’ Is Tense and Deadly Down Unde not found.
# Harold and Lillian’ Introduces a Hollywood Power Coupl not found.
# The Happiest Day in the Life of Olli Maki,’ Love and Life on the Rope not found.
# The Promise’ Finds a Love Triangle in Constantinopl not found.
# Frantz,’ a Mysterious Frenchman and the Wounds of Wa not found.
# Found The Other Half
# Found The Ottoman Lieutenant
# Found Love & Taxes
# Everybody Loves Somebody,’ a Rom-Com With Bit not found.
# Sleeping at 200 requests
# Kedi,’ Rekindling a ‘Love of Life not found.

# %%
# Preview the first 5 results in JSON format
# Use json.dumps with argument indent=4 to format data
# Out:
# [
#     {
#         "title": "The Attachment Diaries",
#         "original_title": "El apego",
#         "budget": 0,
#         "genre": [
#             "Drama",
#             "Mystery",
#             "Thriller",
#             "Horror"
#         ],
#         "language": "es",
#         "spoken_languages": [
#             "Spanish"
#         ],
#         "homepage": "",
#         "overview": "Argentina, 1970s. A desperate young woman goes to a clinic to have a clandestine abortion. As her pregnancy is already through the fourth month, the doctor refuses. Instead, she proposes to sell the baby to one of her clients and offers to provide shelter in her house until the child is born. Their disturbed personalities will become intertwined in a strange and dangerous relationship.",
#         "popularity": 0.708,
#         "runtime": 102,
#         "revenue": 0,
#         "release_date": "2021-10-07",
#         "vote_average": 4.0,
#         "vote_count": 2,
#         "production_countries": [
#             "Argentina"
#         ]
#     },
#     {
#         "title": "You Can Live Forever",
#         "original_title": "You Can Live Forever",
#         "budget": 0,
#         "genre": [
#             "Drama",
#             "Romance"
#         ],
#         "language": "en",
#         "spoken_languages": [
#             "French",
#             "English"
#         ],
#         "homepage": "https://gooddeedentertainment.com/you-can-live-forever/",
#         "overview": "When Jaime, a gay teenager, is sent to live in a community of Jehovah's Witnesses in small-town Quebec, she falls madly in love with a devout Witness girl. The two embark on an intense affair with consequences that will reshape the rest of their lives.",
#         "popularity": 12.027,
#         "runtime": 96,
#         "revenue": 0,
#         "release_date": "2023-03-24",
#         "vote_average": 7.643,
#         "vote_count": 21,
#         "production_countries": [
#             "Canada"
#         ]
#     },
#     {
#         "title": "A Tourist's Guide to Love",
#         "original_title": "A Tourist's Guide to Love",
#         "budget": 0,
#         "genre": [
#             "Romance",
#             "Comedy",
#             "Adventure"
#         ],
#         "language": "en",
#         "spoken_languages": [
#             "English"
#         ],
#         "homepage": "https://www.netflix.com/title/81424906",
#         "overview": "After an unexpected break up, a travel executive accepts an assignment to go undercover and learn about the tourist industry in Vietnam. Along the way, she finds adventure and romance with her Vietnamese expat tour guide and they decide to hijack the tour bus in order to explore life and love off the beaten path.",
#         "popularity": 25.369,
#         "runtime": 96,
#         "revenue": 0,
#         "release_date": "2023-04-21",
#         "vote_average": 6.389,
#         "vote_count": 122,
#         "production_countries": [
#             "United States of America"
#         ]
#     },
#     {
#         "title": "Other People's Children",
#         "original_title": "Les Enfants des autres",
#         "budget": 0,
#         "genre": [
#             "Drama"
#         ],
#         "language": "fr",
#         "spoken_languages": [
#             "French"
#         ],
#         "homepage": "https://www.wildbunch.biz/movie/other-peoples-children/",
#         "overview": "Rachel loves her life, her students, her friends, her ex, her guitar lessons. When she falls in love with Ali, she grows close to his 4-year-old daughter, Leila. She tucks her in, looks after her, and loves her like a mother... which she isn\u2019t. Not yet. Rachel is 40. The desire for a family of her own is growing stronger, and the clock is ticking. Is it too late?",
#         "popularity": 16.246,
#         "runtime": 104,
#         "revenue": 0,
#         "release_date": "2022-09-21",
#         "vote_average": 6.9,
#         "vote_count": 137,
#         "production_countries": [
#             "France"
#         ]
#     },
#     {
#         "title": "One True Loves",
#         "original_title": "One True Loves",
#         "budget": 0,
#         "genre": [
#             "Romance",
#             "Drama",
#             "Comedy"
#         ],
#         "language": "en",
#         "spoken_languages": [
#             "English"
#         ],
#         "homepage": "",
#         "overview": "Emma and Jesse are living the perfect life together, until Jesse disappears in a tragic helicopter crash on their first wedding anniversary. Four years later, Emma has found happiness again and is about to marry her best friend when Jesse resurfaces, turning her world upside down and leaving her torn between two great loves.",
#         "popularity": 28.872,
#         "runtime": 100,
#         "revenue": 37820,
#         "release_date": "2023-04-07",
#         "vote_average": 6.681,
#         "vote_count": 36,
#         "production_countries": [
#             "Germany",
#             "United States of America"
#         ]
#     }
# ]

# %%
# Convert the results to a DataFrame
# Out:
#                          title             original_title    budget  \
# 0       The Attachment Diaries                   El apego         0
# 1         You Can Live Forever       You Can Live Forever         0
# 2    A Tourist's Guide to Love  A Tourist's Guide to Love         0
# 3      Other People's Children     Les Enfants des autres         0
# 4               One True Loves             One True Loves         0
# ..                         ...                        ...       ...
# 150              The Last Face              The Last Face         0
# 151              Lost in Paris            Paris pieds nus         0
# 152             The Other Half             The Other Half         0
# 153     The Ottoman Lieutenant     The Ottoman Lieutenant  40000000
# 154             Rich in Love 2            Ricos de Amor 2         0
#
#                                   genre language       spoken_languages  \
# 0    [Drama, Mystery, Thriller, Horror]       es              [Spanish]
# 1                      [Drama, Romance]       en      [French, English]
# 2          [Romance, Comedy, Adventure]       en              [English]
# 3                               [Drama]       fr               [French]
# 4              [Romance, Drama, Comedy]       en              [English]
# ..                                  ...      ...                    ...
# 150                             [Drama]       en  [English, Portuguese]
# 151                            [Comedy]       fr               [French]
# 152            [Drama, Comedy, Romance]       en              [English]
# 153               [Romance, Drama, War]       en     [English, Turkish]
# 154                   [Romance, Comedy]       pt           [Portuguese]
#
#                                               homepage  \
# 0
# 1    https://gooddeedentertainment.com/you-can-live...
# 2               https://www.netflix.com/title/81424906
# 3    https://www.wildbunch.biz/movie/other-peoples-...
# 4
# ..                                                 ...
# 150
# 151
# 152
# 153  https://www.uphe.com/movies/the-ottoman-lieute...
# 154
#
#                                               overview  popularity  runtime  \
# 0    Argentina, 1970s. A desperate young woman goes...       0.708      102
# 1    When Jaime, a gay teenager, is sent to live in...      12.027       96
# 2    After an unexpected break up, a travel executi...      25.369       96
# 3    Rachel loves her life, her students, her frien...      16.246      104
# 4    Emma and Jesse are living the perfect life tog...      28.872      100
# ..                                                 ...         ...      ...
# 150  Miguel, a heroic Spanish doctor, puts himself ...       9.081      130
# 151  Fiona visits Paris for the first time to assis...       6.798       83
# 152  When English Mark surprises his American bride...       1.058       94
# 153  Lillie, a determined American woman, ventures ...      12.097      111
# 154  When the idealistic Paula resumes her work as ...      33.808       89
#
#      revenue release_date  vote_average  vote_count  \
# 0          0   2021-10-07         4.000           2
# 1          0   2023-03-24         7.643          21
# 2          0   2023-04-21         6.389         122
# 3          0   2022-09-21         6.900         137
# 4      37820   2023-04-07         6.681          36
# ..       ...          ...           ...         ...
# 150        0   2017-01-11         5.617         184
# 151        0   2017-01-14         6.051         108
# 152        0   2006-05-15         6.708          12
# 153   413844   2017-03-10         6.150         236
# 154        0   2023-06-02         6.925          60
#
#                     production_countries
# 0                            [Argentina]
# 1                               [Canada]
# 2             [United States of America]
# 3                               [France]
# 4    [Germany, United States of America]
# ..                                   ...
# 150           [United States of America]
# 151                    [Belgium, France]
# 152                     [United Kingdom]
# 153   [Turkey, United States of America]
# 154                             [Brazil]
#
# [155 rows x 15 columns]

# %% [markdown]
# ### Merge and Clean the Data for Export

# %%
# Merge the New York Times reviews and TMDB DataFrames on title
# Out:
#                               title                  original_title    budget  \
# 0            The Attachment Diaries                        El apego         0
# 1              You Can Live Forever            You Can Live Forever         0
# 2                    One True Loves                  One True Loves         0
# 3    The Lost Weekend: A Love Story  The Lost Weekend: A Love Story         0
# 4                A Thousand and One              A Thousand and One         0
# ..                              ...                             ...       ...
# 120            In Search of Fellini            In Search of Fellini         0
# 121                   The Last Face                   The Last Face         0
# 122                   Lost in Paris                 Paris pieds nus         0
# 123                  The Other Half                  The Other Half         0
# 124          The Ottoman Lieutenant          The Ottoman Lieutenant  40000000
#
#                                   genre language       spoken_languages  \
# 0    [Drama, Mystery, Thriller, Horror]       es              [Spanish]
# 1                      [Drama, Romance]       en      [French, English]
# 2              [Romance, Drama, Comedy]       en              [English]
# 3                         [Documentary]       en                     []
# 4                               [Drama]       en              [English]
# ..                                  ...      ...                    ...
# 120                  [Drama, Adventure]       en              [English]
# 121                             [Drama]       en  [English, Portuguese]
# 122                            [Comedy]       fr               [French]
# 123            [Drama, Comedy, Romance]       en              [English]
# 124               [Romance, Drama, War]       en     [English, Turkish]
#
#                                               homepage  \
# 0
# 1    https://gooddeedentertainment.com/you-can-live...
# 2
# 3
# 4    https://www.focusfeatures.com/a-thousand-and-one/
# ..                                                 ...
# 120
# 121
# 122
# 123
# 124  https://www.uphe.com/movies/the-ottoman-lieute...
#
#                                               overview  popularity  runtime  \
# 0    Argentina, 1970s. A desperate young woman goes...       0.708      102
# 1    When Jaime, a gay teenager, is sent to live in...      12.027       96
# 2    Emma and Jesse are living the perfect life tog...      28.872      100
# 3    May Pang lovingly recounts her life in rock & ...       2.368       97
# 4    Struggling but unapologetically living on her ...      11.704      116
# ..                                                 ...         ...      ...
# 120  Lucy, a small-town girl from Ohio, discovers t...       4.103       93
# 121  Miguel, a heroic Spanish doctor, puts himself ...       9.081      130
# 122  Fiona visits Paris for the first time to assis...       6.798       83
# 123  When English Mark surprises his American bride...       1.058       94
# 124  Lillie, a determined American woman, ventures ...      12.097      111
#
#      ...                                      headline.main headline.kicker  \
# 0    ...        ‘The Attachment Diaries’ Review: Love, Sick            None
# 1    ...  ‘You Can Live Forever’ Review: Do You Love Me ...            None
# 2    ...     ‘One True Loves’ Review: A Romance Lost at Sea            None
# 3    ...  ‘The Lost Weekend: A Love Story’ Review: When ...            None
# 4    ...  ‘A Thousand and One’ Review: A New York Love S...   Critic’s Pick
# ..   ...                                                ...             ...
# 120  ...  Review: Love of Il Maestro Drives ‘In Search o...            None
# 121  ...  Review: Aid Workers in Love and War in Sean Pe...            None
# 122  ...  Review: Finding Love (and Slapstick) While ‘Lo...            None
# 123  ...  Review: A Combustible Pair Find Love in ‘The O...            None
# 124  ...  Review: Love as the World Wars, in ‘The Ottoma...            None
#
#      headline.content_kicker  \
# 0                       None
# 1                       None
# 2                       None
# 3                       None
# 4                       None
# ..                       ...
# 120                     None
# 121                     None
# 122                     None
# 123                     None
# 124                     None
#
#                                headline.print_headline headline.name  \
# 0                               The Attachment Diaries          None
# 1                                 You Can Live Forever          None
# 2                                       One True Loves          None
# 3                      The Lost Weekend:  A Love Story          None
# 4              An Unbending Will Meets a Shifting City          None
# ..                                                 ...           ...
# 120                               In Search of Fellini          None
# 121                                      The Last Face          None
# 122                                      Lost in Paris          None
# 123  Review: A Combustible Pair Find Love in ‘The O...          None
# 124  Review: Love as the World Wars, in ‘The Ottoma...          None
#
#     headline.seo headline.sub           byline.original  \
# 0           None         None    By Jeannette Catsoulis
# 1           None         None  By Elisabeth Vincentelli
# 2           None         None             By Brandon Yu
# 3           None         None            By Glenn Kenny
# 4           None         None         By Manohla Dargis
# ..           ...          ...                       ...
# 120         None         None        By Monica Castillo
# 121         None         None            By Glenn Kenny
# 122         None         None         By Ben Kenigsberg
# 123         None         None           By Andy Webster
# 124         None         None        By Neil Genzlinger
#
#                                          byline.person byline.organization
# 0    [{'firstname': 'Jeannette', 'middlename': None...                None
# 1    [{'firstname': 'Elisabeth', 'middlename': None...                None
# 2    [{'firstname': 'Brandon', 'middlename': None, ...                None
# 3    [{'firstname': 'Glenn', 'middlename': None, 'l...                None
# 4    [{'firstname': 'Manohla', 'middlename': None, ...                None
# ..                                                 ...                 ...
# 120  [{'firstname': 'Monica', 'middlename': None, '...                None
# 121  [{'firstname': 'Glenn', 'middlename': None, 'l...                None
# 122  [{'firstname': 'Ben', 'middlename': None, 'las...                None
# 123  [{'firstname': 'Andy', 'middlename': None, 'la...                None
# 124  [{'firstname': 'Neil', 'middlename': None, 'la...                None
#
# [125 rows x 31 columns]

# %%
# Remove list brackets and quotation marks on the columns containing lists
# Create a list of the columns that need fixing


# Create a list of characters to remove


# Loop through the list of columns to fix

    # Convert the column to type 'str'


    # Loop through characters to remove


# Display the fixed DataFrame
# Out:
#                             title                  original_title  budget  \
# 0          The Attachment Diaries                        El apego       0
# 1            You Can Live Forever            You Can Live Forever       0
# 2                  One True Loves                  One True Loves       0
# 3  The Lost Weekend: A Love Story  The Lost Weekend: A Love Story       0
# 4              A Thousand and One              A Thousand and One       0
#
#                               genre language spoken_languages  \
# 0  Drama, Mystery, Thriller, Horror       es          Spanish
# 1                    Drama, Romance       en  French, English
# 2            Romance, Drama, Comedy       en          English
# 3                       Documentary       en
# 4                             Drama       en          English
#
#                                             homepage  \
# 0
# 1  https://gooddeedentertainment.com/you-can-live...
# 2
# 3
# 4  https://www.focusfeatures.com/a-thousand-and-one/
#
#                                             overview  popularity  runtime  \
# 0  Argentina, 1970s. A desperate young woman goes...       0.708      102
# 1  When Jaime, a gay teenager, is sent to live in...      12.027       96
# 2  Emma and Jesse are living the perfect life tog...      28.872      100
# 3  May Pang lovingly recounts her life in rock & ...       2.368       97
# 4  Struggling but unapologetically living on her ...      11.704      116
#
#    ...                                      headline.main headline.kicker  \
# 0  ...        ‘The Attachment Diaries’ Review: Love, Sick            None
# 1  ...  ‘You Can Live Forever’ Review: Do You Love Me ...            None
# 2  ...     ‘One True Loves’ Review: A Romance Lost at Sea            None
# 3  ...  ‘The Lost Weekend: A Love Story’ Review: When ...            None
# 4  ...  ‘A Thousand and One’ Review: A New York Love S...   Critic’s Pick
#
#    headline.content_kicker                  headline.print_headline  \
# 0                     None                   The Attachment Diaries
# 1                     None                     You Can Live Forever
# 2                     None                           One True Loves
# 3                     None          The Lost Weekend:  A Love Story
# 4                     None  An Unbending Will Meets a Shifting City
#
#   headline.name headline.seo headline.sub           byline.original  \
# 0          None         None         None    By Jeannette Catsoulis
# 1          None         None         None  By Elisabeth Vincentelli
# 2          None         None         None             By Brandon Yu
# 3          None         None         None            By Glenn Kenny
# 4          None         None         None         By Manohla Dargis
#
#                                        byline.person byline.organization
# 0  [{'firstname': 'Jeannette', 'middlename': None...                None
# 1  [{'firstname': 'Elisabeth', 'middlename': None...                None
# 2  [{'firstname': 'Brandon', 'middlename': None, ...                None
# 3  [{'firstname': 'Glenn', 'middlename': None, 'l...                None
# 4  [{'firstname': 'Manohla', 'middlename': None, ...                None
#
# [5 rows x 31 columns]

# %%
# Drop "byline.person" column

# %%
# Delete duplicate rows and reset index
# Out:
#                             title                  original_title  budget  \
# 0          The Attachment Diaries                        El apego       0
# 1            You Can Live Forever            You Can Live Forever       0
# 2                  One True Loves                  One True Loves       0
# 3  The Lost Weekend: A Love Story  The Lost Weekend: A Love Story       0
# 4              A Thousand and One              A Thousand and One       0
#
#                               genre language spoken_languages  \
# 0  Drama, Mystery, Thriller, Horror       es          Spanish
# 1                    Drama, Romance       en  French, English
# 2            Romance, Drama, Comedy       en          English
# 3                       Documentary       en
# 4                             Drama       en          English
#
#                                             homepage  \
# 0
# 1  https://gooddeedentertainment.com/you-can-live...
# 2
# 3
# 4  https://www.focusfeatures.com/a-thousand-and-one/
#
#                                             overview  popularity  runtime  \
# 0  Argentina, 1970s. A desperate young woman goes...       0.708      102
# 1  When Jaime, a gay teenager, is sent to live in...      12.027       96
# 2  Emma and Jesse are living the perfect life tog...      28.872      100
# 3  May Pang lovingly recounts her life in rock & ...       2.368       97
# 4  Struggling but unapologetically living on her ...      11.704      116
#
#    ...  word_count                                      headline.main  \
# 0  ...         295        ‘The Attachment Diaries’ Review: Love, Sick
# 1  ...         294  ‘You Can Live Forever’ Review: Do You Love Me ...
# 2  ...         320     ‘One True Loves’ Review: A Romance Lost at Sea
# 3  ...         327  ‘The Lost Weekend: A Love Story’ Review: When ...
# 4  ...         971  ‘A Thousand and One’ Review: A New York Love S...
#
#    headline.kicker  headline.content_kicker  \
# 0             None                     None
# 1             None                     None
# 2             None                     None
# 3             None                     None
# 4    Critic’s Pick                     None
#
#                    headline.print_headline headline.name headline.seo  \
# 0                   The Attachment Diaries          None         None
# 1                     You Can Live Forever          None         None
# 2                           One True Loves          None         None
# 3          The Lost Weekend:  A Love Story          None         None
# 4  An Unbending Will Meets a Shifting City          None         None
#
#   headline.sub           byline.original byline.organization
# 0         None    By Jeannette Catsoulis                None
# 1         None  By Elisabeth Vincentelli                None
# 2         None             By Brandon Yu                None
# 3         None            By Glenn Kenny                None
# 4         None         By Manohla Dargis                None
#
# [5 rows x 30 columns]

# %%
# Export data to CSV without the index
